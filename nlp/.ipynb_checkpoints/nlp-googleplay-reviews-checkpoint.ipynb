# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('./google_play_reviews.csv')
train_data.head()
# Out:
#    num           date  rating    userName  \
# 0    1   2022년 9월 29일       5         황재준
# 1    2  2019년 11월 28일       5  Google 사용자
# 2    3   2020년 1월 20일       5  Google 사용자
# 3    4   2020년 3월 12일       5  Google 사용자
# 4    5   2020년 6월 17일       5        렛츠고흐
#
#                                              content
# 0  이 게임이 갓게임인 이유 1.5성은 극악의 확률이다. 이런것 없이 5성닌자들이 많이...
# 1  게임 재밌게 잘하고있습니다. 근데 요번에 업데이트를 한 후 버그가 약간 있는것같습니...
# 2  게임방식이 직관적인 반면 스킬 조합 부분에서는 흥미가 일만한 퍼즐 요소가 있어서 굉...
# 3  정말 제 인생겜입니다, 컨트롤이 중요시되며 좋은 아이템도 많이 드랍해주어서 무과금도...
# 4  게임 다 좋고 재밌습니다. 자기 노력만 있다면 투자한 시간만큼 스펙업도 됌 아직 수...

# %%
train_data['label'] = ''

# %%
train_data.loc[(train_data['rating'] > 3), 'label'] = 0
train_data.loc[(train_data['rating'] < 3), 'label'] = 1

train_data.head()
# Out:
#    num           date  rating    userName  \
# 0    1   2022년 9월 29일       5         황재준
# 1    2  2019년 11월 28일       5  Google 사용자
# 2    3   2020년 1월 20일       5  Google 사용자
# 3    4   2020년 3월 12일       5  Google 사용자
# 4    5   2020년 6월 17일       5        렛츠고흐
#
#                                              content label
# 0  이 게임이 갓게임인 이유 1.5성은 극악의 확률이다. 이런것 없이 5성닌자들이 많이...     0
# 1  게임 재밌게 잘하고있습니다. 근데 요번에 업데이트를 한 후 버그가 약간 있는것같습니...     0
# 2  게임방식이 직관적인 반면 스킬 조합 부분에서는 흥미가 일만한 퍼즐 요소가 있어서 굉...     0
# 3  정말 제 인생겜입니다, 컨트롤이 중요시되며 좋은 아이템도 많이 드랍해주어서 무과금도...     0
# 4  게임 다 좋고 재밌습니다. 자기 노력만 있다면 투자한 시간만큼 스펙업도 됌 아직 수...     0

# %%
train_data[train_data['rating'] == 1]
# Out:
#        num          date  rating    userName  \
# 6        7   2020년 6월 7일       1         정승환
# 16      17   2019년 9월 9일       1  Google 사용자
# 17      18  2020년 5월 16일       1         끾끾이
# 22      23  2021년 4월 22일       1         이형준
# 27      28  2020년 3월 15일       1  Google 사용자
# ...    ...           ...     ...         ...
# 5910  5911  2020년 6월 20일       1         남주영
# 5916  5917   2020년 8월 1일       1          ??
# 6056  6057  2021년 3월 25일       1        골드버튼
# 6258  6259  2020년 5월 28일       1         박종호
# 6440  6441  2020년 4월 25일       1  Google 사용자
#
#                                                 content label
# 6     업데이트 자주 되는 점 때문에 참고 계속 해보려고 했는데, 더이상은 못참겠네요. 뭔...     1
# 16    오늘 깔았는데 20스테이지에서 자꾸 다운돼서 게임진행을 못하고 있습니다. 그리고 상...     1
# 17    지금 이게 몇 번이에요...저번엔 도시 스테이지 중간보스에서 로딩화면만 떠서 3번이...     1
# 22    이번에 업데이트를 하고 광고를 하나 볼때마다 에러창이 뜨면서 게임이 정상적으로 작동...     1
# 27    답변 바랍니다 게임을 하고 싶은데 실행하고 5~6분정도가 지나면 와파 풀인데도 불구...     1
# ...                                                 ...   ...
# 5910                                              게임 하고     1
# 5916                                                개꿀잼     1
# 6056                                                 노잼     1
# 6258                                                 너잼     1
# 6440                                                엄준식     1
#
# [467 rows x 6 columns]

# %%
labeled_data = train_data

# %%
train_length = labeled_data['content'].astype(str).apply(len)
train_length.head()
# Out:
# 0    396
# 1    226
# 2    204
# 3    162
# 4    215
# Name: content, dtype: int64

# %%
train_length.describe()
# Out:
# count    6600.000000
# mean       23.047879
# std        39.272438
# min         1.000000
# 25%         4.000000
# 50%        11.000000
# 75%        26.000000
# max       500.000000
# Name: content, dtype: float64

# %%
train_review = [review for review in labeled_data['content'] if type(review) is str]
train_review
# Out:
# ['이 게임이 갓게임인 이유 1.5성은 극악의 확률이다. 이런것 없이 5성닌자들이 많이나와 키우는 잼이 있다. 2.내맘대로 술법을 골라쓰는 재미가 있다.이 게임엔 연출이 화려한 술법들이 많다.그레서 눈을 호강 시키며 몬스터들이 있었는데 없어져서 정말 좋다. 3.스테이지가 많아 아주 좋다.차근차근 스테이지를 깨가며 나름대로 스토리도있고 재미 있다.막히는 부분은 공략법을 보며 닌자들을 육성해 깨가는 재미가 있다. 단점은 대요괴 토벌에서 좋은 장비가 나오는 확률이 너무 극악이다.먼가 5성닌자뽑는것에 확률을 몰빵하고 이것을 극악으로 낯춘것 같다.근데예외도 있다.잘나오는 사람도 분명 있을거다.하지만 그레도 확률을 조금더 올렸음 좋겟다. 그레도이겜은 갓겜이다. 아무튼 만드신 분들 고생 많으셨고 수고하셨어요.~~^^',
#  '게임 재밌게 잘하고있습니다. 근데 요번에 업데이트를 한 후 버그가 약간 있는것같습니다. 대전댁이 2시간마다 변경될수있도록 됬는데요 대전댁이 아닌 일반댁을 바꿔도 대적댁 시간이 2시간으로 리셋되더라고요 확인부탁드려요 그리고 업데이트이후에 서버에러가 자주 나오기시작합니다 또 장비를 바꾼 후 전투력이 변화되는데요 덱에 현제상태저장을 눌러도 전투력이 이전과 그대로 나옵니다. 업데이트 감사합니다 고생하셨어요^^',
#  '게임방식이 직관적인 반면 스킬 조합 부분에서는 흥미가 일만한 퍼즐 요소가 있어서 굉장히 재밌습니다. 또한 한 스킬 사용시 다른 스킬을 동시에 시전할 수 있어서 속도감이 있어서 좋았습니다. 카툰식 디자인이나 깔끔한 인터페이스 등 그래픽적인 부분도 흠 잡을데 없어요. 아직 플레이를 길게 해본 것은 아니라 단점이라 할만한 부분을 발견 못했네요. 흥미가 이는 게임입니다.',
#  '정말 제 인생겜입니다, 컨트롤이 중요시되며 좋은 아이템도 많이 드랍해주어서 무과금도 과금러 뺨치는 수준으로 플레이할수 있습니다. 또 각 스테이지마다 전략을 세워서 플레이를 해야지만 스테이지를 클리어할 수 있기 때문에 전략을 세우는 재미가 있습니다. 정말 꼭 한번 플레이하시기를 추천드립니다.',
#  '게임 다 좋고 재밌습니다. 자기 노력만 있다면 투자한 시간만큼 스펙업도 됌 아직 수정할 부분은 좀 있지만 신규게임에 이 정도면 완성도 높음. 캐릭이 2등신이라 너무 귀여움ㅋㅋ 하나 아쉬운건 전용 아이디를 개설할 수 있었으면 좋겠습니다. 핸드폰을 새로 바꿨는데 그 전 폰으로 해서 새로 깔면 사라져서 아쉽습니다. 아이디를 만들수 있게해주셔서 다른 폰으로도 접속할 수 있었으면 좋겠습니다!',
#  '쉬운 조작에 단순한 디펜스 게임같은 구조를 하고 있지만, 다양한 모드와 뉴비도 쉽게 템을 바꾸면서 올라가는 전투력을 보는 재미는 지금껏 해본 게임중 가장 강력한 중독성을 가지고 있다고 생각합니다. 괴력난신 세트 이후에 약간의 슬럼프가 왔지만 그걸 견뎌내는 순간 재미는 배가 될거라고 확신합니다',
#  '업데이트 자주 되는 점 때문에 참고 계속 해보려고 했는데, 더이상은 못참겠네요. 뭔 놈의 버그이 파도파도 계속 나오죠?? 스킬 쓰다보면 주인공이 사라지질 않나, 스킬 효과는 적용도 안되고, 무슨 게임이 얼마나 무거우면 스킬 사용시 프레임드랍이 발생하나요? 진짜 업데이트 과정 중에 문제가 있나 싶어서 재설치 몇 번을 하는지.. QA가 일은 하는지 궁금해지는 게임입니다. 와중에 광고는 많이 하시던데, 게임 스타일과는 전혀 다르게 광고하시면 흥미가 생길까요?? 다른 문제를 고치는 것도 중요해 보이는데, 광고가 먼저였을까요?? 별점 한개??? 별점이 한개 미만으로 안내려가는게 다행이라고 생각해주세요 아참, 댓글 수정 작성 기준으로 한달 반이나 지났는데.. 종료버튼은 아직도 없더군요. 이벤트를 바라는게 아닙니다. 적어도 게임이 돌아가는데 이용자의 목소리는 제대로 들어야하지 않을까요??',
#  '게임 자체는 재밌음 그런데 스킬 밸런스 차이가 너무 심해요. 어떤 스킬은 고정으로 가져가고 다른 스킬은 아예 버려야되요. 공략안보고 어떤 스킬이 좋은지 모르면 게임 진행이 안됩니다. 저도 지금 그런 구간에 막혀서 캐삭해야되게 생겼어요. 상황에 맞춰서 다양하게 스킬 구성해서 진행하는 재미가 있었으면 했는데 아쉽네요.',
#  '게임은 잘 만들었습니다. 캐릭터도 귀엽고 인터페이스 조작도 쉽게 접근 가능합니다. 그런데 초반 시작시 보상이 부족한 느낌이 많이 듭니다. 5성급 캐릭터들을 얻기가 힘들어서 초반에 육성할때 동기부여가 잘 안됩니다. 5성이 좋다, 필요하다고 느껴야 다른 캐릭도 키워보고 싶은 마음이 들텐데 얻기가 힘들어서 게임을 하고싶은 마음이 들지 않네요...',
#  '일단 재미있다. 하지만 올라가는 스테이지를 따라갈 수 없어 자연스럽게 과금이 필요하도록 한다. 플레이 1일차부터 이런 벽에 막히게 된다. 많은 시간들여 극복할 수 있지만, 극복 후에는 또 다른 난관이다. 이 게임에서 스킬 의존도는 높은 편으로 보인다. 앞서 말한 높은 난이도와 더불어 수동 플레이를 요구하기에 긴 시간의 노가다가 필요하다. 요괴를 잡아 아이템을 갖출 수 있지만, 한번에 최대 3번이라는 횟수는 단기간 성장을 막는다. 오래 플레이하지 않아 잘 알 수 없지만, 유저간 대전은 약간 불공평 하다. 금화를 써 상대를 바꿀 수 있지만, 상대 유저 풀이 작은지 몇번 바꾸고나면 다시 똑같은 상대다. 초보자는 스킬업에 필요한 돈만 날리고 패배를 피할 수 없게된다. 대전 보상은 초보자에게 큰 도움이 되는데, 이러한 굴레에 빠지게 되면 보상수령까지 수많은 패배를 경험하게된다.',
#  '광고보기해서 무료로 아이템을 얻을라하면 한번보고나서 껏다 다시켜야지 광고를 다시볼수있네요. 그러지않으면 계속 광고준비중으로 있구요.. 그리구 이것저것 눌러서 뭐하거나 스테이지클리어하고 난 후나 로딩이 너무 길어요.. 갤럭시 10 5g인데 폰문제는 아닌거같아요 ㅠㅠ 그래도 게임은 정말 재밋어요! 그래서 참고 계속 하구있어요!',
#  '물론 이 게임이 할만합니다. 눈이 안아픈 스킬과 하나에 스테이지 마다 제가 성장해가는 과정을 보여주니 전 할만 하지만은 현질 유도가 너무나도 심한 것 같습니다. 스테이지를 못 도는 상태에서 너무나도 할수없는게 많습니다. 장비확률도 너무 적고 개선해주었으면은 합니다. 평점 3점드리겠습니다. 앞으로도 재미있는 게임이 되었으면 합니다. 삭제하지 않고 계속 앱에 설치해 둘 겁니다. 감사합니다.',
#  '정말 좋은 갓겜입니다! 하는동안에 수집해서 저의 캐릭터가 삐까번쩍해질때마다 만족감이들며 기분이 좋았습니다. 그런데 성9의 난이도가...정말 어렵더군요 난이도좀 낮춰주시면 좋겠네요 그리고 던전을 도는데 클리어를 했음에도 로딩중표시만 되고 나가면 클리어 보상도 안들어오고 영혼석만 없어지거나 남아있는 경우도 있었읍니다. 고쳐주시면 감사하겠습니다',
#  '스킬을 해금하면서 업글도 할수있어서 재밌음, 그리고 의뢰게시반에서 보스 잡아서 장비 나오고, 나온 장비들로 강해지는게 아주 좋음. 다만 불편한점이 있는데 게임을 하는 도중에 와이파이가 잘 터지는데 자꾸만 무한 로딩이 걸려서 껐다키니까 백섭이 되기 때문에 불편함 무한로딩 좀 어떻게 해주삼',
#  '점점 뒤로갈수록 노가다성이 강해지고 템을 뽑으려는데 뽑는데 게임을 몇백에서 몇천판을 돌려야 하다보니 점점 게임이 반복되고 지루해집니다.뭔가 더이상 게임이 손에 잡히질 않는 느낌이랄까? 이 게임 처음 2달동안 정말 재밌게 플레이했는데 이제 열심히는 아니고 뭐 생각날때마다 한번씩 할것같네요.이런 게임에 기초가 되는 문제라서 딱히 해결방법이 있는것은 아니지만 답답한 마음에 한번 남겨봅니다.',
#  '5성 캐릭 정말 잘나오는 게임입니다 너무 잘 나오니까 누굴 써야할지 어려울정도.. 그리고 스킬도 직접 손으로 그려서 스킬 쓸 때 화면 보는 맛이 있습니다. 광고도 필요할때 보면 되고 좋습니다. 디펜스 게임류인데 스킬도 많고 스킬이 승부에서 중요하기 때문에 컨트롤 여지도 있고 재밌습니다 한가지 건의할 점은 스킬을 사기 전에는 체험할 수 있는데 사고 나면 체험을 못하는게 아쉽습니다. 스킬도 많은데 바꿔끼기 전에 체험 한번 해보고 바꿨으면 좋겠는데 그냥 돈되는대로 샀더니 무슨 스킬인지 확인이 안돼서 직접 장착해서 써봐야한다는 점이 불편하네요 ㅜㅠ',
#  '오늘 깔았는데 20스테이지에서 자꾸 다운돼서 게임진행을 못하고 있습니다. 그리고 상대가 스턴을 당했을때 넉 백 스킬을 쓰면 뒤로 밀려나지 않는데 수정해주시면 감사하겠습니다. 그리고 인벤토리 창이 약간 조잡하다고 해야되나 쓸모없는 아이템들을 모두선택하는 버튼과 팔 수 있게끔 해주시면 감사하겠습니다.',
#  '지금 이게 몇 번이에요...저번엔 도시 스테이지 중간보스에서 로딩화면만 떠서 3번이나 지웠다 깔아도 안 됬고..재미는 떨어졌고,지금은 패치 됬을 거라 믿고 있었습니다.하지만...이번은 더 심각합니다.게임 시작 로딩에서 화면이 막히고 버튼은 눌러집니다.이게 뭔 말이냐면 화면은 로딩인데 실제로는 메인화면이라고요...이러면 강화도 못 하고 스테이지 들어간다 해도 스킬을 못 써요.저는 오락용으론 삼성 태블릿을 쓰는데,그 도시 증간보스까진 아무 문제 없었읍니다.이게 하라고 만든 겁니까?그것만 고쳐주신다면 갓겜입니다.다 좋은데 그거 때문에 팍 망겜 되버렸어요.',
#  '게임자체가 엄청나게 신선한 게임은 아니지만 우리가 아는 익숙함과 우리가 폰으로 누릴 수 있는 편리함 두 개를 모두 잡은 게임. 간편한 조작과 주인공의 외형이 장비를 바꾸면 같이 바뀌는 등의 시스템이 이목을 끌며 독특한 그림체에서 나오는 화려한 스킬들이 게임을 절대 지루하게 끌지 않는다. 주인공을 육성하는 맛, 스킬을 해금하고 쓰는 맛, 그리고 과금을 유도하지 않으며 아이템을 수집하는 맛까지 제대로 살렸다. 다만 4점을 준 이유는 PvP에서는 긴장감이 AI전에 비해 지나치게 떨어지고 재미가 없다. 그리고 컨텐츠가 적어 빨리 질리기 쉬우며 스킬의 종류가 많아보이지만 생각보다 적고 쓰는게 한정적이라 금방 질린다. 재밌는 게임인건 사실, 하지만 결국 나루토의 스킬들 중 가져온 기술이 많아 안 좋은 시선을 갖게 될 수도 있을 것 같다.',
#  '정말 타격감도 좋고 아이템 드랍률은 말할것도 없고 중간중간 나오는 재미를 더해주는 스토리에다가 항상 메일 선물로 오는 영혼석 덕분에 게임 스토리 진행을 맘껏 할수 있고 출석 보상으로 나오는 황금영혼석 덕분에 스토리가 막힌다 싶으면 전판 보스전 토벌로 아이템 벌면 다시 진행이 가능한 데다가 도전 실패하면 영혼석을 돌려주는 시스템 덕분에 덱을 마음대로 바꿔가며 할 수 있다. 또한 타 게임들처럼 보석을 과금해야만 주는 것이 아니라서 무과금으로도 충분히 보석 파밍 가능. 그리고 무조건 강한 스킬들로 덱을 채워서 플레이 해야만 깰 수 있는게 아니라 스킬을 바꿔가면서 전략적으로 플레이 할 수 있다는게 정말 마음에 들었다. 그리고 이런 게임에 성우 보이스가 있을 거라곤 상상도 못했는데 캐릭터마다 목소리가 있어서 캐릭터들의 개성을 잘 살린 게임이다. 그리고 광고 몇번 보는걸로 쓰기에 따라서 엄청난 이득을 볼수 있다. 한가지 바라는 점이 있다면 이 게임이 흥행했으면 하는거다. 한줄요약: 갓겜',
#  '갓겜이라기엔 한물갔다. 운영이나 컨텐즈 업데이트가 정말 오래기다려야 하나씩 나온다. 뉴비들이나 신규유저들이 들어올만큼 뉴비에게 친절한 시스템은 없다. 특히 마을이라는 타게임의 길드와 같은 시스템은 이 닌자대전에선 의미가 없다. 공카만 가도 최소컷이란게 존재하는데 최소컷에 진입하려면 운좋아야 일주일 늦게는 한달이 걸릴수도 있다. 또한 쫄뚝쫄장을 맞춤과 동시에 시작인데 이 과정또한 만만치 않다. 과금을 해도 뽑기 운빨이 극악이며 특정 캐릭터를 제외하곤 버려지는 캐릭터가 대다수다. 몇개월간 플레이를 한 뉴비입장에서는 고인물게임이라고 밖에 평가를 줄 수 없다. 마을 시스템을 갈아 엎지 않는 이상은 부질없는 게임시스템이다. 들어가보아라. 아무도 환영하지 않는 뉴비에게 길드(마을) 시스템은 답이없다. 오죽하면 직접 개설하겠는가. 직접 개설하더라도 마을퀘스트가 상당히 중요한 비중을 차지하는데 뉴비가 마을퀘스트를 깨기란 바위에 계란치기다.',
#  '게임은좋아요!시간날때할수있구요 틈틈히 해도재미있고 심심할때도 하면 잼있어요 근데 아쉬운게3가지 정도있어요 1번뽑기:뽑기가 조금그레요~좋은게잘안나와요 지금4일찬데4성1개...ㅠㅠ 부적도 안좋은거만 나오구요 뽑기확률높여주세요 2번난이도:난이도가 갑자기 확~! 높아질때가있어요 보스나오는 구간말고도 많아요 그레서 뽑기해서 좋은거뽑아야지 앞으로 전진할수있는데 잘안나온다는 것도있어서 광고 많이 봐야되구요 토벌을 많이해야되요 조금 벅차드라구요ㅎㅎ...난이도 하양도 생각해보셧으면 합니다 3번아이템:아이템이 너무안좋아요 반짝반짝 거리것이 기본탬보다 방어력낮아요 2개정도 스택 붙어있어도 그냥 기본옵션만 있는 기본아이템이 훨씬 효율이높아요. 옵션도 있고 방어력도 높은 아이템은 제일높은 수준의 아이템 밖에없어요. 따로 뽑을수있는 아이템 상점도 만들어주셧으면 좋겠네요 드랍율도 조금 높여주시구요 10번토벌하면 4~5번만 아이템나와요 게임 개선좀 부탁합니다. 닌자대전ㅎㅇㅌ',
#  '이번에 업데이트를 하고 광고를 하나 볼때마다 에러창이 뜨면서 게임이 정상적으로 작동이 안되는 현상이 일어나고 있습니다 저는 그 에러라는 창이 뜰때마다 매번 게임을 다시 껏다가 다시 켜야되는 굉장히 귀찮은 상황입니다 신규 유입된지 얼마 되지않아 나름 재미있다고 생각하면서 꽤 열심히 플레이 하고있었는데 갑자기 하고 싶다는 생각이 뚝 떨어지게 되네요 이러한 문제들은 빠르게 고쳐주시면 감사하겠습니다',
#  '대 유잼^^ (big yes jam) 게임을 되게 개성있고 재미있게 만드십니다. 게임을 하면서 아쉬운점이 있다면 타 게임내에서 유저들이 편하게 플레이하는 부분을 좀 더 추가해주셨으면 합니다. 1. 덱편성을 결투장 따로 모험덱 따로 모험덱은 3개이상 되면 더 좋을듯합니다 2. 자동스킬사용기능 아직 게임이 소프트런칭 단계라서 게임의 재미를 저하하는 시스템이니 유명해지고나면 한 번 고려해주세요! 그럼2만! 닌자대전 대유잼^^',
#  '얼마전에 시작한 초보 유저입니다. 간만에 이렇게 재및는 게임은 처음 본거 같네요 장점이 너무 많습니다. 스킬 퀄리티,영웅등등 장점도 많지만 단점도 조금 있네요 스토리를 진행하다 보면 영혼석이 떨어져 다음 껄 시작을 못해서 영혼석을 쉽게 얻을 수 있게 해주시면 감사하겟습니다^^',
#  '기본적으로 재미있습니다. 다만 메뉴 선택 조작감이 여태한 게임 중에서 처음 겪는 조작감이네요..; 한번에 전환이 되지 않는 것이 플레이하는데 지장은 없지만 조금 많이 불편합니다.ㅠ 개선 부탁드립니다.',
#  '일반,고급 등급 아이템 나왔을 때는 광고보고 추가로 얻기해서 잘 나오던 광고가 신화등급 아이템을 얻고 광고보기 누르니 준비되지 않았다 합니다. 한 두번도 아니라서 일부러 그렇게 설정한 듯한 느낌을 받습니다. 평가글이라서 솔직하게 말씀드립니다. 혹시 제 어감이 기분을 상하게 했다면 미리 죄송합니다. 더 나은 게임을 위해 개선 부탁드립니다.',
#  '답변 바랍니다 게임을 하고 싶은데 실행하고 5~6분정도가 지나면 와파 풀인데도 불구하고 계속 끊깁니다. 수정하겠습니다 . 불행하게도 제가 최근 가장 재밌게 즐기던 게임이 닌자대전이였습니다. 그런데 무엇이 문제인지 이제는 접속을 하는 과정에서 튕깁니다.... 젭속을 가까스로 한 적이 있습니다. 이제는 안 끊겼으면...하고 있는데 바로 30초뒤에 튕기는 매직을 보았습니다. 이게 도대체 무슨 상황인지...',
#  '스테이지가 늘어날수록 난이도와 들어가는 돈은 많아지지만 획득머니가 너무 작습니다. 1스테이지 중간보스가 1300원을 주는데 4스테이지 19라운드가 1300원이면 너무 수지타산이 맞지않습니다. 그리고 게임에 이벤트와 퀘스트가 너무 부족합니다. 퀘스트가 스테이지를 진행해야지만 가능하것 뿐이라 사람들이 게임에 쉽게 질리기 쉬울거같습니다',
#  '아주 잼있네용 다만, 스킬 쓸 때 내가 스킬 쓸 곳 터치한 이후에 한 번 더 스킬이 사용되어지는 부분이 표시 되었으면 좋겠어요 아님 스킬 쓸 때까지 쭈욱 표시되어있던가 빠르게하다가 그냥 내 캐릭터 자리가 찍힐때 있는데 그 때 제대로 쓴 줄 알고 연속으로 스킬 써서 낭패를 보는 경우가 쫌 나오네요 그거말곤 다른 건 다 짱짱!!',
#  '(급) 게임종료 버튼이 없는건가요 아님 제가 못찾는건가요? 뒤로가기 버튼을 눌렀을때 게임종료버튼이 있다면 좋겠어요 아직 많이 해보지는 않았지만 흥미로운 게임이네요 캐릭터간 밸런스 조절을 어떻게 하는지가 관건일거 같네요 부디 캐릭터간 개성과 능력을 상황에 따라 적절히 바꿔가는 그런 전략게임이 되면 좋겠어요',
#  ":: 요약 :: ①내 인생게임이다. ②오픈단톡방은 소외감 느껴질 수 있다. 질문을 해도 답변 받기는 쉽지않다. (1000명을 넘겼으나, 나가고 들어오고를 반복중이다./알람은 끄고, 자신의 닉네임을 키워드 설정하는 것을 추천한다.) ③그러니 카페에서 질문을 하거나, 검색해보자! ④국민 덱 [수3 목3]은 고정이고, [토2, 환2, 체4, 그 외 등등] 잘 맞쳐쓰는 것 같다. 도움이 되었다면 떠따떠따 구독해주면 좋고요~~ (전문가 처럼 보이려고 흉내를 내는 거지 전문가는 아닙니다.. 또르륵...) 안녕하세요. 닌자대전 무과금 5일차 '떠따떠따'입니다. 이게임닉네임은 '떠따' 이고, 닌자대전 오픈단톡방 닉네임은 'o떠따떠따[5일차]【닌자대전】'입니다. 튜토리얼 잘 따라하시고, 기억해뒀다가 요래 조래 만지작하시면 점점 능숙해지고, 이것 저것 다 보면 이런식으로 돌아가는 구나를 알 수 있습니다. 5일차인 저도 다 마스터한 것은 아니지만, 성-8 까지 클리어하였습니다.",
#  '작년에 하다가 어려워져서 지우고 올해 다시하기 시작했는데 역시나 재밌고요^^ 무지 무지 넘나 아쉬운게 하나있는데요ㅠㅠ 전엔 공격할때 화둔!!목둔!!토둔!! 하는 성우님 목소리가 나와서 뭔가 속시원한 재미도 있고 이게임 얘기하면 그부분이 퀵.포인되서 그소리로 즐거움을 야기했는데 왜 이번엔 나오질않고 훅훅훅하는 손 모션 소리만 들릴까요?? 설정을 잘못해서인지 알려주세요~~~~ 아무리 찾고 설정해도 나오질 않네요.. 너무 아쉽습니다 다시 나오게 하는 방법좀 알려주세요오ㅠ',
#  '게임은 재미있습니다만 현질로 빠른 성장 기대하시는 분들은 비추입니다. 왜냐면 장비구하는게 극악입니다..장비 획득확률이 초극악인거만 빼면 만족스럽게 하고있습니다. 공식카페에는 대부분 몇개월 만에 얻는다는데 누구는 3일차에 그냥 구했다더군요.. 현타 쎄게 왔지만 현질하면 한달은 해보는 성격이라.. 저도 현질 통해서 보석 다 박았는데 정말 안나옵니다.. 확률게임 싫어하시는분은 비추합니다.',
#  '어렵지않고 가볍게 할수있어서 좋네요^^ 그런데 스테이지마다 아이템최상옵이 나오는걸로 되있는데 너무 희박하네요 너무 다운시켜놓은건 아닌지... 가끔 먹는재미도 있으면 좋겠어요^^ 그리구 5분순삭이라...안할때 안하더라두 15판하는건 너무짧고...100이나 아니면 15판씩 주는걸 자주줬으면 좋겠어요!!',
#  '게임은 재밌게 플래이 하고 있습니다. 그런데 순수대련에서 상대방 공경력이 너무 높게 잡혀서 계속 패배만 하는데 초보자들한테 불리한거 같습니다. 매칭을 공경력 비슷한 사람들끼리 만나게 하면 더 좋을거 같습니다.',
#  '광고선택가능.(시청시 적절한보상) 그래픽이 일관성있게 재미있음. 아직 컨텐츠는 부족하나 술법을 통해 몰려오는 적을 물리지늘 디펜스류의 재미요소가 확실함. 요즘 손놓고 감독같이 케릭터 영입과 배치에만 신경쓰는 게임에 질린분께는 확실한 기분전환이 됨. 그 이상은 좀더 해봐야 알겠음',
#  '타격감이 예술인 하나의 평작 1.일단 타격감애기를 안할수가 없다. 각각의 특성에따른 효과와 이펙트가 게임의 재미를 먹여살렸다 다만 쓰는것만 쓰이고 다른건 예능으로 쓰이는 스킬들이 많고 환술 체술이 스킬수가 적어 그것만 파서 본인만의 세계를 걸을수가 없다는게 좀 아쉽다. 2.난이도벨런싱 문제. 성9는 말할것도 없고 이미 벨붕이 유명하니깐. 기본적인 스토리는 현질이나 큰 노가다 없이 깨게끔 만드는게 가장기본적인 옳은 설계라고 생각한다. 기본스토리 그후 추가컨텐츠(캐릭스킨.보스전등등)나 추가스토리에서 현질이 선택적 사항 이 되게끔 하는게 좋은데 이 게임은 그걸 실패했다. 갈수록 노가다와 기다리는 건 기본. 원거리몬스터의 대미지설정도 실패하여 스트레스만 유발한다 원거리몬스터 때문에 쓸모있는 스킬만 쓴다; 즉 자유도 별로없음 3.가끔 로딩중 0퍼와 50퍼를 수 없이 오가며 로딩이 안되는 버그가 있다. 게임종료버튼 좀 만들어주라 뒤로가기 눌러도 안나가져 일좀해요 +(정성들인 답변이라 5점박고감',
#  '게임은 재밌으나 각각 스테이지별 난이도가 높아 성장하기위해 많은 시간을 투자해야 하는 게임 그러나 게임은 재미있어서 천천히 게임을 오래하시는 분한테 추천드리나 좀 게임을 급하게 하시는 분은 난이도때문에 열 받을 수 있어 그런 분은 안하시는 걸 추천드려요',
#  '갓갓갓겜 인데 공식카페 좀 확인하세요. 스킬 벨런스(계수) 같은거는 수치 계산하면 금방 패치할 수 있잖아요. 아직 뉴비여서 하루하루가 재밌지만 공카에 들어가면 버그에 벨런스로 말이 너무 많아서 벌써부터 걱정이 됩니다. 좋은 게임은 출시시점에서 끝나는게 아니잖아요. 운영도 중요합니다. 그럼 ㅎㅇㅌ',
#  '복귀유저입니다. 지금도 재밌긴한데 코인떼문에 인술을 사지 못하고 있습니다. 옛날에는 전투를 할때마다 이겼지만 현재는 계속 지는 수준입니다. 복귀 유저예게 코인과 뽑기를 무료로 나눠주는것도 나쁘진 않을겁니다. 다만 복귀유저들은 차이가 너무 심해서 현질유도가 많이 되니까. 제발 무료로 골드나 캐릭 뽑기좀 주면 감사하겠습니다.',
#  '안녕하세요 게임을 재밋게 하고 있는데 아이폰으로 할 때는 안그랬는데 갤럭시 폴드2 로 기기변경을 하고 하니 화면 하단 부분이 짤려서 보이지 않습니다... 수정 되면 좋겠습니다.',
#  '스테이지 클리어중 막혔을때 해결방안도 많고 다 좋습니다 근데 닌자 레벨업이 너무 느린것 같아요 1.5배만 경험치 휙득이 높아져도 정말 재밌을 것 같습니다',
#  '아주아주 재미있고 훌륭한 겜인데... 닌자자릭터 다른 ~륜들은 각성이있는데 수륜만각성이 없네요 황실정예 수륜 만들어주시면 감사하겠습니다.',
#  '이거 18 이벤트 보상받는것도렉걸려서 몇번씩 팅기는건지 공략도 거지같고 걍 게임이답이없음 템파밍? 은 한달해도 제자리걸음',
#  '광고제거 구독취소가 왜 개월 일시정지 밖에없죠? 한달만 하고 안하려고 했는데 어떻게 된건가요?',
#  '아니 무슨 와이파이쓸때는 에러 안걸리거니 데이터만 쓰면 자꾸 에러가 걸립니다 이것좀 고쳐주세요 제발 pls',
#  '안녕하세요 닌자대전을 시작한지 1주일 된 유저입니다 저는 닌자대전을 즐겨했는데 이번에 업데이트가 안돼서 지웠다가 다시 깔았는데 계속 팅김 현상이 일어납니다 주변 제 친구도 이런 현상이 나타났는데 이거 정말 재밌는데 지금 팅김 때문에 보상도 못받았습니다ㅠㅠ 제 글을 보셨다면 제발 이 현상을 고쳐주실수 있을까요?ㅠㅠ',
#  '몇번이나 에러로 나가지는지 모르겠네요. 아무 전조도 없이 에러가뜨고 껏다켰다 반복하다가 리뷰남겨요..',
#  '요즘은 재미없어서 자주안하지만 아무리그래도 현질을 그렇게했는데 3일째 접속이 안되는데 조치를 안한다는건 그냥 유저를 ㅈ으로 아는거라고 생각할수 밖에 없습니다',
#  '업데이트 하면 게임이 안켜집니다 공식카페 들어가보세요 개선도 안하고 운영진이 돈에 맛들려서 소통 전혀안하고 패키지만 만들생각만하고 업데이트 할때 마다 이러니까 답이 없습니다. 제발 이런 발전없는 게임 돈쓰지마세요',
#  'ㅋㅋㅋㅋ 쓰레기게임 방치운영 2틀동안 제대로된 접속도안됨 본인들이 테스트도안해보고 유저상대로 테스트하다가 이번에 지대로 물림 특정기기라는데 안드로이드 구버전말곤 대부분 접속안됨 과금은 메이저게임 뺨따구 칠정도임 무능을넘어 무지함',
#  '1년전 별점5개 주면서 극찬했는데 이제는 추천안합니다 업데이트 할때마다 역대급 오류가 생겨서 유저 스트레스받게 만들어요',
#  '이번 업데이트 되면서 게임을 들어가면 검은 화면이 뜨면서 바로 튕기면서 나가지는데 이건뭐죠?(저는 스마트폰 유저입니다)',
#  '업데이트이후, 키자마자 꺼집니다 재설치를 해도, 폰재부팅을해도 마찬가집니다',
#  '다 좋은데 스테이지 난이도가 너무 어려워요 좀 낮춰주세요 그러면 5점이에요',
#  '구독 광고제거 자동결제취소부탁드립니다 이메일보냈는데 답변도 안하시고 자동결제 왜이렇게설정하셨나요? 수령안하였으니 취소부탁드립니다',
#  '재미있지만 게임난이도가 너무어려습니다. 초반에는 쉬우나 중반부터 똑같은 맵인데 어떠한 스테이지 난이도 가 갑자기어려워지는등 게임 난이도에 대한 것에대해 수정을 해주시길바랍니다. 그것빼고는 재밌는 게임 입니다.',
#  '후반으로가면 스테이지가 어려워서 막힐때가 있습니다. 그러면 계속 이렇게해야합니다. 1.괴물 토벌,2.스테이지돌리면서업글하고...이렇게반복만하는 노가다 게임이돼네요....중간마다 뭘추가하면 좋을듯 그리고이겜은 유저들이 고치라는거는 안고치고 신규닌자만출시하고 아무도안사는패키지만 만드니깐 욕을먹는거임',
#  '막 뿌리지도 않고 열심히 하는만큼 주는게임 원했는데 딱 이게임 같네요 항상 응원하고 게임듀오 화이팅!!',
#  '정말 재미있어요! 하지만 지금은 버그 때문에 게임에 들어가지지 않아요ㅠㅠ 재발 고쳐 주세요ㅠ',
#  '신규 재밋게 잘하고있는데요 업데이트 이후로 앱을 눌러도 실행이 안되여.. 3일째 닌자대전 금단현상 ...힘듭니다..',
#  '업데이트후 계속 튕겨 못들어감.재설치해도 안들어가짐',
#  '광고만 보면 겜튕기는것만 사라지면 재밌게할거 같아요 ㅠ.ㅠ',
#  '로딩하다 팅겨서 접속도 못하고 뭐하는건지..',
#  '업데이트후 접속안돼서 삭제도해봤는데 계속 접속안되고 바로튕깁니다ㅡㅡ',
#  '이번 패치이후에 게임접속자체가 안됩니다. 그래서 지우고 재설치도 해보았지만 역시 마찬가지입니다. 폰 기종은 갤럭시 s21+입니다.',
#  '가볍게 즐기기도 좋고 잘만들었네요',
#  '점심 저녁때 보상 주는거 받는순간 멈춰서 받으려면 재접해야함...',
#  '내인생 폰게임 중에서 최고의 게임 황금패 많아졌으면 좋겠다',
#  '초반에는 할만한데 아직 시스템이 단순하지는않음 이것저것 뭐가 많음',
#  '아니 게임은 재미있는데 버그떼문에 화가나네요 아니 전투력15만 이었는데 갑자기 9만으로 떨어졌어요 이 버그 고쳐주세요',
#  '최근에 한 게임 중 가장 재미있어요 몰입할 수 있는 요소들이 많아요.',
#  '업데이트이후로 게임 접속이안됩니다 빠른픽스부탁드립니다.......',
#  '별점 드립니다. 또 드릴 수도 있습니다. 지옥주세요. 많은거 안바랍니다 지옥무 하나만 힣',
#  '이 게임은 정말 제미있습니다. 하지만 게임 조금 후반만 가도 장비를 얻기위해 노가다를 합니다. 이 게임을 처음 접했을땐 이만한 갓 겜이 없었습니다. 하지만 노가다가 심해지며 이 게임이 눈에들어오지도 않을 정도로 지루합니다. 뭔가 큰 이벤트 혹은 제이있는 포인트, 노가다를 줄이면 더욱 좋을겄 같습니다.',
#  '오랜만에 다시 쓰네용 ㅎㅎ 어느새 난문까지 왔는데요 ㅎㅎ 아이템 복사 붙여넣기 기능을 만들어주셨으면 좋겠어요 하나의 스테이지를 여러가지 방면으로 연구하면서 깨는게 너무 재밌고 콘텐츠가 많아서 즐길거리가 많은 대신 템도 게속 바꿔줘야해서 너무 번거로워요 ㅎㅎ',
#  '처음엔 성장하는 재미와 여러 개성 넘치는 닌자,술법을 사용해 보는 즐거움도 같이 선사하였지만 공략글을 안보고 진행하면 무조건 막히게 되어있으며 후반으로 갈수록 똑같은 짓이나 합니다. 대요괴 토벌-(이벤트 던전 있을때만)-여러 던전들-20개 정도 되는 마을임무-외곽임무-일일 퀘스트-성장하면 스토리 밀기 이거의 반복이고 점점 후반으로 갈수록 이 노가다의 강도가 심해지고 귀린담 같은 성장에 중요한 장비는 거짓말 안하고 1000번을 해도 안뜹니다. 게다가 하라는 버그는 안고치고 신규닌자나 계속 출시하고 최근에는 각성닌자 까지 출시하고 있네요. 각성,스킬9강을 찍을려면 10명 이상의 동일닌자가 필요합니다. 물론 여러 편의성 패치와 사료를 많이 뿌려주지만 당장 공식카폐만 보아도 게임에 대한 불평이 매우 많습니다... 참... 버그만 잘고치고 컨텐츠좀 다듬고 소통만 좀 더 잘하면 5점 이상도 줄수있을거같은데... 개인적인 평으론 가끔 시간 때우기로 적당한 게임인것같네요. 5점 만점에 3점!',
#  '반가운 소재! 참신한 설정 ㅋㅋㅋㅋㅋ 기대이상의 퀄리티에 놀랐습니다. 구성이 다체로워 오래할수있을듯!! 퇴근길에 다운받았는데 간만에 꿀껨 발견ㅋㅋㅋㅋ 빡겜중입니다!!',
#  '재미있는 게임인 건 부정하지 않지만 부족한 컨텐츠와 그 부족한 컨텐츠 또한 오랜 시간동안 즐길 수 없다는 아쉬움이 있습니다. 초월석과 핏빛 영혼석을 다 소모하면 할 게 없을 뿐더러 이 초월석과 핏빛 영혼석은 마음안 먹으면 30분 내로 다 쓸 수 있습니다. 이 노가다를 끝내고 나면 즐길 다른 컨텐츠 또한 없어 다소 게임을 하는 와중에도 따분하다는 느낌을 받게 됩니다. 물론 게임은 계속 할 겁니다ㅎㅎ',
#  '다시 깔아서 재밌게 플레이중입니다! 근데 문제가 좀 있는데요 다시 깔았을때 예전 데이터를 불러올거냐는 메시지가 나오지않아서 예전데이터는 다 사라졌겠구나싶어서 새로 열심히 키웠습니다. 근데 어느순간부터 재접속을하면 예전 데이터를 불러올거냐는 메세지가 뜨더라고요. 취소를 눌러도 계속뜨고 지금 키우고있는 계정을 계속 키우고싶은데 계정연동버튼을 누르면 예전 데이터를 다시 불러올거냐는 메세지가 다시 뜨는데 예전 데이터를 삭제하고 지금 키우고있는 계정을 새로 연동시키는 방법은 없나요? 연동을 못시키면 실수로 삭제하거나 폰을 바꾸는 순간 데이터가 사라지는건데 그건 싫어서요.',
#  '예상보다는 상당히 잼잇네요 아직 초보라... ^^ 이정도 광고는 머 봐도 상관없죠 아직은 현질 안하고 잘하고 잇어요...광제만 몇번함',
#  '업데이트를 했는데 게임 실행이 안됩니다..',
#  '아니 제발 오류 좀 고쳐요 전투 도중에 스킬 사용하려고 스킬 누르면 스킬은 안써지고 스킬아이콘만 사라져있을 때도 많고.. 스킬을 분명 제대로 썼는데 다른 곳에 써질 때도 엄청 많습니다.. 그거 없애려면 나갔다가 다시 들어와야 되는데 로딩이라도 빨리 되던지.. 계속 하기도 지쳐서 접습니다 제발 좀 고치세요',
#  '업데이트후 게임 실행 자체가 안되네요',
#  '작화가 훌륭하고 재미도 있지만 진짜 1시간동안 버그로 팅긴게 3번입니다.',
#  '초반에 유저 이탈을 맞는게 가장 중요한데.. 초반이 너무 지루합니다. 몹은 적고 게임은 빨리 끝나지만 공격속도도 느려서 게임이 느리게 느껴지는 마법.. 이렇게 재미없게 만드는것도 재능이라면 재능.',
#  "업데이트하고 실행이안됩니다'어째하나요'",
#  'Uuid 에러가 뭔가요 접속이 안되네요;',
#  '완전 최고에요~! 전부 좋고 아쉬운점은 동페,은페,금페 얻기 힘들어요..... 추가해줬으면하는 기능은 스토리(만화)를 볼 수 있는 창을 만들어줬으면 해요..... 감사합니다!',
#  '그냥 너~~~~~~~~~무 재미있어요 랙도 안걸리고 아니 그냥 네 스타일^^',
#  '기대 이상의 재미를 주는 게임 이네요.',
#  '재미있게잘하고있어요 에러가나는데 수정해주세요',
#  '재미는 있는데 문제가 너무 많다. 난이도 어려움, 좋은 장비 드랍률 너무 낮음, 영혼석 수급도 문제있고, 돈이랑 금패도 너무 안주심 난이도를 낮춰서 게임진행을 원활하게 하던가, 장비 드랍률을 높여주던가 해야지 발전이 없다.',
#  '너무 재미있네요 하지만 컨텐츠가 좀 부족한거 같고 계속 노가다 돌리면서 광고봐야 해서 겜에 대한 기억보다 광고에 대한 기억이 더 많이 남네요 ㅎ.. 그래도 최적화 및 버그수정 하시니 나름 만족합니다 ㅎㅎ 앞으로도 초심 잃지 말고 닌자대전 홧팅!',
#  '이 게임을 좋아하는 유저로서 말하겠습니다 일단 뭐 성 8 9 이런건 한 일주일정도만 광고보면서 노가다 조금만 하면 깰 수 있어요 공략도 있으니 괜찮다 치고 ... 그리고 성9 이후에 맵이 나와도 사람들은 가지각각 공략을 내세우며 깨는거에 재미가 들것이기 때문에 그쪽은 문제가 없다고 생각합니다. 제 생각중 하나 문제는 길드라고 생각하는데.. 길드 임무 좋아요 뭐 보상도 짭잘하고요 주간임무 깨고 일일 임무 몇개 깨면 길드는 들어가지도 않게됩니다 뭐 게임 특성상 길드 전쟁같은거 못하긴 한다지만 그래도 길드에 손좀 대주셨으면 좋겠습니다 제가 팀게임을 좋아해서 항상 게임하면 길드에 애정을 쏟게 되는데 이건 애정을 쏟고싶어도 그럴 수가 없네요 부탁합니다',
#  '옛날 때 정말정말 재밌게 하던 게임이라서 오랜만에 해봐야지 하고 깔고 접속을 하는데 접속이 안되고 갑자기 화면이 멈추더니 튕깁니다. 오류 겠지 하고 하루 기다렸다가 다시 해봤는데 안되고 삭제했다가 다시 깔아도 튕겨요. 저 이겜 꼭 하고 싶습니다.',
#  '질리던와중에 꾸준히 하긴했는데 이번 업데이트로 기존에 비해서는 컨텐츠도 조금더 많아지고 다양해진거같네요 근데 맵도 늘어나고 했는데 몹은 재탕에 기존 사냥방식이 단조로워서 크게 바뀐부분이 없다고 느껴집니다 이부분은 개선이 필요한거같네요',
#  '재밌게 즐기고있는데 한번씩 에러코드가 뜨네요 확인부탁드립니다',
#  '오랜만에 복귀해서 하려고 했는데 핸드폰 바뀐것도 아니고, 계정이 바뀐것도 아닌데 자꾸 18/19 에서 약 5분동안 로당되다가 19/19가 되고, 로딩 창이 나옵니다. 그러고 나서 갑자기 로딩 게이지는 올라가는데 0%로 올라가다가 98%에서 숫자가 바뀝니다. 그러고 100%가 되면 갑자기 노래가 안나오면서 홈 화면으로 튕깁니다. 이게 이상한게 보통 게임이 튕기면 구글 서비스에서 이 앱이 계속 중지됨 이라면서 보고 할것입니까? 라고 창이 떠야 정상인데 이 튕김 현상은 그런창도 없이 그냥 튕김. 예전에 잘만들고 재밌어서 하려했더니 갑자기 이게 어떻게 된일이죠? 빠른 버그 픽스 바랍니다. 리뷰 보니까 저 하나만 이 현상이 일어나는것도 아닌것 같은데. 빠른 픽스 부탁드립니다.',
#  '매우 재미있는 게임입니다. 그런데 은패5개로 뽑기를 돌릴라고 했는데 튕겨서 다시 들어갔는데 은패5개는 사라져있고 캐릭터는 없음니다. 은패를 돌려주시면 5×99999999999999999점은 드릴 수있읍니다.',
#  '아직 단순하고 컨텐츠가 한정되어 있지만 앞으로 기대된다.(버그 수정도 너무 늦는다.) 요즘 한국갬이 과금 패키지나 월정이 중국갬보다 창렬해지는데 이 게임도 마찬가지라 아쉽다.',
#  '전에 깔았다 지우고 다시 즐기고 있는 유저입니다😚 예전에는 버그가 없었습니다😀 하지만 업데이트가 된후 로딩을 할때 버퍼링인지 렉인지 다음화면으로 넘어가지 않아져요😣 다른건 잘 되고 재밌어요😊추천합니다😘',
#  '쉽게 즐길 수 있어 좋습니다 단 다른 게임에 비해 일일 퀘스트나 주 퀘스트가 부족하며 그에 대한 보상이 적은 것 같고 전반적으로 아직까지 즐길만한 컨텐츠가 많이 부족한게 아쉽습니다',
#  '메인 캐릭터도 귀엽고 다 좋은데 플레이를 하면 할수록 현질을 안하고 하기엔 좀 힘든 게임이였습니다ㅠ 아이템 얻기도 힘들고 랩업 하는것도.. 하지만 그레픽이나 그런 나머지들은 다 좋았습니다!',
#  '솔찍히 성 5단계 난이도 낮혀주면 안돼나요?? 지금 거기에서 10일동안 막혀서 할맛이 안나요 어떤사람은 무기 캐릭터 레벨 거의 전설급에다가 5성짜리로 깔맞춤해서 겨우께는데 심심풀이로 하는사람이 그걸 어떻게 합니까 ㅠㅠ 난이도 조정 해놨다 해서 들어갔는데 조금은 변화가 있는것 같은데 막힌건 막혀있어요 ㅠㅠ 제발 성단계좀 난이도 하향좀 ㅠㅠㅠ부탁드려요 ㅠㅠㅠㅠ',
#  '영혼석 수급에 너무 문제가 많은것같아요. 지금 단계는 한판당 3개가 소모되고 나중에는 판당 10개가 소모되고 10분 기다려야 한개...최대 영혼석을 늘려주시던지 판당 영혼석 사용은 줄이던지 수급을 많이해주던지... 30분기다려서 광고 한번에 한판이라니.. 힘이 다 빠지네요 영혼석 수급을 늘려주세요 골드 벌기 너무 빡세니까',
#  '현질해서 은패로 두루마리 깟는데 무한로딩 걸리더니 앱껏다켯더니 계속 검은 화면만 나오다가 8번정도 반복하니 겨우 접속은 됫는데 두루마리랑 은패는 날아갔네요. 게임은 재밌는데 복구해주실지...',
#  '안녕하세요 닌자대전을 플레이하고있는 유저 입니다 일단 전채적인 게임은 좋습니다 하지만 다른유저랑 싸울때 밸런스가 너무 안맜습니다 저는 10만도 못같는데 상대방은 몇 십만....몇백... 등 너무 밸런스가 안맜아 밸런스패치 부탁드립니다 그리고 매일 한 번 고급 두루마리를 깔수있는건 좋은것 같습니다 그리고 배5엣 막히고 있습니다 바로 상태이상 무적 몬스터 입니다 피도 너무많고 밀리지도 않고 기절도 않통합니다 피를 주려주시면 좋겠습니다 그리고 확률이랑 승급할때 5성으로 승급할때 4성 4명....너무 많습니다 2명으로 줄여주시면 감사하겠 습니다 그래도 저가 별 4개를 준 이유는 게임이 제미있고 손으로 챱챱챱챱 이런거 정말 좋은거 같습니다 나름 스토리도 잘 구연해놨구요 정말 좋은게임 같습니다 지금까지 긴 글 읽어주어 감사합니다',
#  '이게임 은 좋은게임입니다 근데 2점 만주는이유는 도시 스테이지 20 보스 전에서 보스 가 투명 해져서 채력만 표시되고 다른 잡몹 들 은다죽였는데 보스가 투명으로 표시되고 게임 이끝나지않습니다 그리고 시간 초과로짐..... ... 그래서 도시 를 못넘어가고 있으니 .... 이점 만 보안하면 5점 입니다',
#  '아니 스킬 배우면서 강한 옷이 나오면서 재밌어요 근대 모르는사람이랑 전투 하면 강한 사람이 나오잖아요 그걸 체인지 할려고하는데 자꾸 버퍼링이 걸리고 로그인중... 뜹니다 내폰이 문제인지 아니면 그쪽 서버가 문제인지..;; 빨리 고쳐주시면 좋겠습니다',
#  '아니 어제부터 계속 게임 로딩도 개느리고 겨우 로딩돼서 들어가면 게임 한판 하거나 합성하거나 마을출첵등등등 갑자기 로딩뜨면서 계속 로딩화면이고 게임이 진행이 안됩니다. 게임을 삭제하고 다시 깔고 해봐도 똑같아요. 게임 왜 이러죠?',
#  '게임은 중독성있게 플레이했습니다 다만 광고혜택아이템이 시간이 10분 20분 등 피로도가 엄청쌓이게 끔 구성되어있어서 지쳐서 못합니다 현질하지 않으면 마냥 게임을 수시로 끼고키고해서 광고만 주구장창봐야하며 경험치 골드수급도 시간투자를 많이해야합니다 또한 고인물이 혜택 몰아받게끔 경쟁시스템이 되어있습니다 길드 및 대전은 뉴비들이 경쟁에 참여할려면 왠만한 현질 시간투자 아니면 격차는 어마어마하게 벌어질겁니다 엔드급까지 성장하지 않으면요 하실분들은 참조하세요 끈기있고 시간많으신분들은 추천드립니다',
#  '기본적으로 그래픽과 퀄리티가 좋습니다. 그리고 캐릭터가 잘나와 성장이 빠르고, 전장에서 쓰는 재화가 없습니다. 그러므로 재화를 더 아낄 수 있죠. 전 아직까지 스테이지가 막히는 것 말고는 큰 불편함을 느끼지 못해 아주 만족스럽습니다.',
#  '안녕하세요 게임 재밌게 잘 하고있습니다 닌자 증발현상으로인하여 문의메일을 보냈는데 연휴기간이라 확인이 안되는건가요? 버그게시판에도 남기고 메일로도 2번정도 보냈는데 따로 답변메일온것도 없고 해서요.. 게임은 스테이지 뚫는재미가 있습니다 스킬 조합해서 뚫는맛이 상당하네요',
#  '그래픽도 너무 귀엽고 마음에 들고 게임도 재밌습니다. 왠지모르게 유머러스한(?) 그래픽과 어울리지않는 고퀄더빙도 입덕포인트에요. 한참 재밌게 즐길수있을것같아요.',
#  '확실한 컨셉이 있는 그래픽 스타일에 지루하지 않은 스킬. 그리고 게임의 주 스타일이 자동전투면 게임이 금방 질려버리는데 이 게임은 지루하지 않습니다. 적재적소에 스킬을 쓰는 재미가 있는 그런 게임 입니다. 흔한 디팬스게임과는 다르네요. 오래 할듯 합니다.',
#  '두루마리에서 5성이 확률이 너무 적구요 전투력이 높아도 10000이나 전투력 낮은 동생에게 발립니다 동생은 성8 격파 했는데 저는 아직 못하구요 금패 얻기도 너무어려워서 5개 모으기 힘들구요 몬스터 다죽일때 시간과 동시에끝나면 무조건 격파를 못하는 설정이구요 현질유도도 있구요.. 특별히 이벤트로 금패를 얻는것도 아니고 무과금으로 플레이 하니깐 영혼석 충전은 시간이 오래걸리고 핏빛 영혼석이랑 이가의 증표도 더 오래걸리는데 거기다가 시간에 걸쳐서 만땅으로 채우면 더이상 안얻어지고 보석쓰라하고 보석없으면 현질해라 그렇게 유도하고 아이템 얻는 확률도 적은데다가 캐릭터는 부족하고 금,은,동패는 부족해서 보석쓰고 보석다쓰고 없으면 현질해라 이게 말이 됩니까... 게임은 즐겁기위해 하는건데 노가다로 지루하고 고쳐주었음 좋겠네요..금패 얻기가 너무 어려워서 아쉬워요',
#  '이런 느낌의 디펜스 게임이 정말 하고싶었습니다.. 너무 재밌네요.. 캐릭터 성우도 괜찮구요 한가지 건의할 점은 사용할수있는 스킬창을 좀 더 늘려줬으면 하네요 스킬은 정말 다양한데 그에 반해 쓸수있는 스킬은 부족하다고 느껴집니다..',
#  '흠 예전에 재밌게 해서 다시 깔아보려는데 깔고 들어가니 에러라고 뜨네여? 그래서 서비스 종료했나 하고 게임 설명창에 들어가서 확인해 봤는데 별로 그런 얘기는 없고 최소사양 이야기가 있어서 확인해 봤는데도 최소사양보다 제 폰이 더 좋더라고요;; 이게 뭔 오류인지 알아봐 주시고 고쳐주세요',
#  '처음에는 할만하다고 느꼈지만 현질을 하지 않는 이상 할 수 있는 게 없어지는 걸 느낌 굳이 현질을 할 가치도 없어 보이고 몇 개 없는 컨텐츠즁 순수 대련은 누가 매칭 시스템을 만들었는지 몰라도 일단 생각이란 걸 할 줄이는 놈이 만든 건 분명 아닌 것 같음 아니면 전투력이 수십 배나 차이 나는데 붙이니',
#  '광고 하나보면 계속 준비중이네요 보려고 해도 볼수도 없고 의뢰퀘스트 할때마다 광고 준비중이 걸려서 추가템을 못먹은게 몇번인지.. 원래 이런건가요..',
#  '6개월간 매일매일 무과금으로 눈뜨자마자 하고 4시간에 한번씩 풀접속 하면서 느낀점 전해드립니다.마을 7렙 운영, 캐릭터 거의 6성 전투력3천만이상.주인공 장비 전부 전설9강 부적제외. 이후 발전이 안됩니다.두달간 정채중입니다.8~9강9~10강 하는데 천만금화정도 필요합니다.장비 강화에 개선필요해보입니다.',
#  '재밌네요. 근데 광고시청을 거의 다 했는데 보상으로 아무것도 안들어오네요. 이게 무슨 경우죠. 이런거 처음보는데 버그 언제 고치나요? 무슨 광고료 기부하는 것도 아니고 기분이 좀 그렇네요. 그리고 녹색재료 써서 스테이지 진입시 연결끊기면 재료 그냥 공짜로 하나 날아가네요..ㅎ',
#  '이겜 무언가 잘만들엇다지만 그렇지만하면할수록 무언가가 결여된거같은데 라고느꼇을때떠나라 박수쳐줄텡게 ㅜㅜ 잘만들어놓고도 운영을개판으로하느냐 이제서야이겜을접하고 4일차된뉴비닷 공략글안보고시작햇다가 무언가 이상해서 공략글을보앗더니 졸작 졸뚱이잇다는걸 저랩템으로 얼마나많은부가가치를높여주는지...깨닫게해주는게이거야이거',
#  '너무 재미있고 만족합니다 근데 그 영혼석 때문에 게임을 못하겠서요 그래서 영혼석 이라는 시스템을 삭제하고 그냥 게임을 하게해줫으면 하는 바램이 있습니다 아니면 그냥 영혼석을 많이주던가 그렇게 하면 더 인기가 많아 질 꺼 같아요 저는 노가다를 많이하는 유저라서 영혼석이 없으면 게임을 못해요 노가다를 많이하는 유저 입장으로에 생각은 이렇습니다 닌자대전을 오래한 유저로 닌자대전이 인기가 많은 게임이 돼면 좋겠습니다 화이팅!!!',
#  '쉽게 접할수있으면서 중독성이 강한게임같아여 공략도 보면서 조합짜는것도 재미있네요 변기 앉아서 1시간동안 했는데 지루하지도 않았고 캐릭터 들이 개성 넘쳐서 뽑을때 마다 기대하게 됩니다ㅋㅋ',
#  '아이폰으로 하는데 게임센터로 계정을 만들었더니 블루스택 프로그램에서 로그인이 안되는게 불편하네요 시작한지 며칠안되서 그냥 구글계정으로 새로 만들어서 다시 키워보는중인데 게임자체는 단순하면서 저는 새로운게임이라 그런지 나름 흥미를 갖고 재밌게 하고있습니다 근데 블루스택에서는 광고시청하고 받는 재료들이 처음 한번 시청하고 받고나니 광고준비중에서 바뀌지않네요 아이폰에서는 금방 바뀌어서 모든재료 다 받았었는데 블루스택에서 할때는 1가지 받고나니 안되서 아쉽네요 그냥 안되는건지 ..',
#  '게임성 자체는 매우 훌륭하다. 하지만 과금 없이 게임 하기엔 지원이 너무 없고 컨텐츠는 부족한데 시간을 오래 들여야 성장이 가능하다. 하지만 그동안 질리는게 단점.',
#  '투력 3000만 4달한 뉴비입니다.. 술법,닌자,템들을 조합해 스테이지를 깨어 나가는 맛으로 하는건데 스테이지마다 격차가 너무 큽니다. 타 게임처럼 이지/하드로 나누고 스테이지간의 난이도 격차를 줄이면 정말 좋을것 같습니다!! 항상 수고들하십니다~',
#  '제가 모바일 겜중에 가장 좋아하는 게임이에요 ㅎㅎ 아쉬운건 광고를 자주 봐야하는것이고 템 뜨는 확률이 좀 적다 정두.. 그래도 공략보고 열심히 하다보면 점점 쌔지고 시간날때 가끔씩 들어와서 즐기면 굿굿',
#  '적의 어렵게 깨치는 하지만 근데 정말 재미있습니다 게임을 강력 추천하지는 않지만 게임을 어려운 걸 좋아하시는 사람들은 재밌을 거에요 하지만 어려운 단계가 진짜 너 진짜 많이 가지 나와서 약간 어려운 걸 좋아하지만 어려운 거 좋아한다고 해요 그러면 처음에 쉬운 게 안 나와요 많이 가진 나와요 그래 그 그런 분들은 추천 안 하겠습니다 하지만 너는 처음해 신갈 도 괜찮다 그러면 추천합니다 이 게임을 전 정말 재밌게 했습니다 추천 (갑자기.겜이. ..삭제......)',
#  '하...... 현질유도 심하네요. 그리고 6-몆스테이지 어떤 보스 나오는데 어떤보스는 걍 몆마리씩 나오고,제작자님 이거 버그인가요?아님 제작자 님이 현질 유도하라고 만든건가요?거의다 좋은 장비였는데 제즉자님이 너무 밸런스를 안맞게 헤놓아서 어렵습니다.그리고 또한가지 영웅뽑기에서 좋은것도 나왔는대 6-몆스테이지 때문에 지웠습니다. 제가 리뷰작성한것을 보시고 이것들을 싹다 고쳐주세요.고쳐주시면 다시 하는 건 생각할게요.안고쳐 주신다면 기분이 나쁩니다. 또 현질이 너무 비싸내요. 이거는 현질 너무 심합니다. 게임 초반에는 쉬워요. 6 몆 스테이지는 너무 어렵습니다.',
#  '재밌어요. 근데 영혼석 시스템을 없애 주셨으면 합니다. 게임을 플레이 하다보면 어느샌가 영혼석이 다 없어져 있어서. 게임플레이를 잘 못할때가 많습니다. 그래서 토벌만 영혼석이 들게하고, 그냥 플레이는 아무 재약 없이 그냥 플레이 할수 있었으면 합니다. 게임은 정말 재미있어요!',
#  '게임 자체는 캐릭터들의 밸런스와 스킬들을 키우는 맛이 있는게임입니다 즐길수있는 시스템들도 다양하구요 하지만 가끔씩 게임에 접속하면 바로 튕기는 현상이 있는데 고쳐주시면 감사하겠습니다',
#  '생각외로 너무 재밌게하고있구요 골드많이 얻을수있는 이벤트, 퀘스트를 많이해서 좋네요~ 다만 퀘스트가 조금더 다양했으면 좋겠어요!',
#  '5성캐릭이 정말 잘 뜹니다. 문제라고 하자면 캐릭을 진화시킬려고 하는데 4성이 필요할때 5성이 너무 잘 떠서 4성이 잘 안뽑힌다는 점 제외하고는 정말 좋습니다.',
#  '다 좋은데 스테이지마다 격차가 왜 그렇게 어렵게 만든거임? 니들이 게임을 하고 정한 거 맞음? ㅋㅋ 무슨 한 스테이지 깨고 다음 스테이지 가면 겨우 깨는것도 아니고 아예 못 깨는 수준인데 ㅋㅋ 공략 보고 해도 며칠은 더 해야 가능할 수준이던데 그 며칠 동안은 하지 말라는 건가 ㅋㅋ 진짜 역겨움 ㅋㅋ',
#  '진짜 너무 갓겜이에요. 마나라던가? 그런것도 없고 타격감도 있고 성장도 빨라요. 그리고 무과금도 쉽게 할수 있어요.진짜 칭찬할 점밖에 없네요. 앞으로도 닌자대전처럼 좋은게임 많이 만들어주셨으면 합니다',
#  '게임은 재미있고 좋은데 처음에 들어가 지지도 않고 튕기거나 게임이 끊기거나 그래픽이 깨져서 나온다거나 너무 버그가 많아서 게임 플레이가 어려울 정도입니다;; 수정해주세요',
#  '실망입니다. 게임 처음 깔았을 때 부터 계속 로딩중에 튕겨서 게임 한판도 못했습니다. 최근에 다시 깔아봤지만 여전히 접속은 안되네요. 무책임하게 무시하지 마시고 답글이라도 달아주고 해결하고있다는 성의를 보이시라고요.',
#  '업데이트 이후에 아에 접속이 안되네요',
#  '상당히 재밌고 나름 괜찮은 컨텐츠와 생각보다 잘만든 캐릭터(장비에따라 주인공 모습이 조금씩 변한다!)로 유저의 재미를 더한다. 그리고 나루토의 일부 설정들을 자신만의 것으로 소화해 기존 나루토 팬들의 대리만족도 느낄 수 있어 시간나면 한번씩 해보자.',
#  '전설닌자뽑기를 15번했는데 다 4성임... 홧률좀 높여줘요.. 그리고 성 7단계에서 마지막 괴물죽이고 죽는 임팩트까지 떠서깬줄알았는데 시간초과로 무효되는건 좀 너무한듯... 성에서 한단계깰 때마가 주는 보상도 성7단계올때싸지 한번도 못받아서 토벌로만 아이템 얻음..솔직히 보상만이라도 무조건 나오게해줘라.. 일반등급이라도..',
#  '게임 자체는 정말 재미있어요 하지만 금패나 영혼석 수급에 있어서 정말 문제가 많다고 생각합니다 특히나 금패수급에 비해 효율이 너무 좋지않네요 현질을 하지않고서야 못버티는 무과금유저들만 우는 게임이네요 게임자체는 너무 재미있는데 안타깝습니당 ㅠㅠ',
#  '성장하기 너무힘들어요!!! 재미있지만 경험치수급이나 골드수급이 느리다보니 전반적 육성이 느려 다소 지루할수 있는거 같으며, 과도한 과금유도로 장기유저감소 할수도있을거같네요. 개인적인 의견입니다.',
#  '재미는 잇어요 근데 업데이트하고 점검 보상 업데이트 보상 이런거 없나요?? 가뜩이나 보상 도 안좋은데 .. 그리고 성우분들.. 화둔 목둔 수둔 이렇게만 그냥 끊으니까 감질맛남... 다른 표현 써서 끝까지 기술 이름을 말하는게 더 좋을거 같네요..',
#  '세로 게임은 제가 안좋아 하는데 이건 뭔가 오묘하게 빠져요. 세로는 칠대죄나 무계 같은것만했는데 금방질려서 지우고 깔고를 계속하는데 이건 1~2달 정도 논스톱으로 하네요. 재밌는 게임 만들어 주셔서 감사합니다.',
#  '정말 재미있고 갓게임입니다. 다만 한가지 오류가 있어 말씀드리자면, 부적 합성하려고 하는데 장착되어있지않은 부적이 자꾸 장착되어있다고 합성을 못하게해서 좀 짜증이 납니다. 이 부분만 조속히 해결해주시면 감사하겠습니다. 감사합니다.',
#  '어디하나 흠잡을때 없음 가끔 막히는 것은 시간을 들여서 캐릭터를 업그레이드하고 깨는 맛이 있습니다. 무과금으로도 충분히 가능합니다.',
#  '1년 사이에 분위기가 확 달라진 게임. 안좋은 쪽으로',
#  '진짜 얼마만에 갓겜을 찾은건지 요즘 이게임만 하고있어요 중간중간에 막히는부분도 있지만 그런것덕분에 더 재미있게 할수있어요 게임이 너무 쉬우면 재미없잔아요? 그리고게임도 간단하고 너무재미있게하고 있습니다. 완전 추천!! 꼭해보세요!!',
#  '디펜스게임을 좋아해서 정말 재밌게 하고있습니다. 근데 강화나 뽑기를 할 때 한번에 여러 개를 넣거나 뽑을 수 있으면 좋을거같습니다.',
#  '재미부분은 시간상 좋아요 그래도 현질이 너무 필요하고 금,은 뽑기 모으기가 많이힘들어요..무과금 유저도 할수있게 셋팅이 더욱 필요해 보입니다~',
#  '정말 재미있습니다! 줄여서 장점줄여서4개만 말할게요!(장점더많아요) 1 뉴비들이 쉽게할수있다 2 시간가는줄 모른다 3 헤택을 많이준다 4 재미있다! (제작자님 힘내세요!)',
#  '와...... 플레이 할때마다 느끼는데 정말 재미있습니다!!!!!@!',
#  '광고를 강요하지 않고, 사용자가 추가 아이템을 원할때 광고를 보면됩니다. 나의 능력치를 조금씩 높여가는 재미가 있습니다. 추천합니다.',
#  '양산형게임인줄 알았으나 캐릭터, 아이템, 스킬조합이 생각보다 정교하게 설계되어 있어 도전욕구를 불러일으키네요. PVP이펙트부족(화려하지 않고 보상이 약함) 및 마을간 대전 부재가 아쉬운 점입니다.',
#  '나루토 보루토를 좋아하는데 닌자게임이 있어서 좋네요!! 그리고 나선환 에토전생을 좋아하는데 다른 인도 해주시면 고맙겠습니다!!! 그리고 나루토 바탕을 한걸 찾아볼 수 있습니다. 체술은 록리가 가아라와 싸울때 썼던 초사이언화가 되는걸 바탕으로 하는 것같아요!!',
#  '이 게임 1년 전부터 했는데 제가 아는 디펜스 게임중 최고입니다. 이만큼 재밌고 컨텐츠도 다양해서 좋지만 5성이 좀더 잘 나오거나 금을 신규유저에게 푸짐하게(10회뽑) 주는 이벤트 같은게 있으면 좋겠네요',
#  '단순한 디펜스 게임이겠거니 하고 시작했는데 진짜 전략적이고 재밌습니다 시간 투자하는 만큼 스펙업도 잘되고 뉴비들을 위한 업데이트도 해서 진입장벽이 생각보다 낮습니다 카페도 활발하니 한번쯤 플레이 해보세요 시간 진짜 잘갑니다 ㅋㅋ',
#  '처음 시작할땐 밤늦게까지 재밌게 했습니다 다만 후반부로 갈수록 너무 재화 마이닝 게임이 되어가는건 어쩔 수 없겠지만 아쉬워요 ㅠ 무탑 일던 등 재화수급 개선을 해주셨지만 레이드 외에도 숙제로 느껴지지 않을 컨텐츠가 있었으면 하고 바랍니다..',
#  '소소하게 재미보기 좋은 게임이네요',
#  '그리 어렵지도 않고 현질이 광고와 매 맵마다의 보상 덕분에 현질 없어도 됩니다. 퀄리티도 좋구여... 재미까지',
#  '이 게임에서 개발 손 놨죠? 작년에 했을때랑 변한게 진짜 하나도 없네요 유저를 위한 업뎃이 진짜 거의없는듯 ㅋㅋㅋ 마치 10년전 게임들이 유저들한테 알아가는거도 일종의 게임을 즐기는 방법임 ㅋ 그러니 안알려줘도 알아가셈 하는 느낌 이랄까 다행히 2일차부터 현질하는 제 게임 방식이 이게임에선 없었어서 다행',
#  '진짜 잽있는데, 늦게 알아서 아쉬운게임 언제 남들만큼 키우지..ㅡ^^',
#  '게임자체는 너무 재미있는데 광고를보면 게임이 멈춰서 안되고 게임을하면 배경이 검정으로되고 로딩이되다가도 안되서 계속 튕기네요 게임을 더 재미있게 즐길수있도록 빠른 조치부탁드립니다',
#  '신박하고 좋은데 성 마지막 스테이지가 너무 갑자기 어려워지는게 허들도 높고 말도 안되는 수준이라 접었네요... 재미는 있지만 레벨난이도 설정이 개판인거 같습니다.',
#  '정말 참신하고 재밌게 하고있는 게임입니다 한가지 추가하면 좋을것 같은 기능이 있는데 스킬미리보기 기능에 무조건 그스킬만 쓰게하는게 아니라 기존자신의 스킬들과의 궁합을 확인할 수 있게 자신의 스킬도 쓸수있게 해주셨으면합니다',
#  '정말 재미있고 쉽고 빠르게할수있어요^^ 그런데 전투하기전에 아이템이하고 전투를 하고 아이템이 달라요.🤩 그것만 고쳐주세요!!',
#  '구글에서도 영상으로 나오고 하길래 해보고 싶어서 다운 받았는데 처음 달이 웃는 애니메이션 부분 넘어서 할로윈 일러스트 로딩 부분이 계속 0%→80%만 왔다갔다 하면서 게임 자체가 실행이 되지 않습니다. 다른 비슷한 용량 게임은 안그런데 아쉽네요.',
#  '아니 다좋은데 자동장착이 안되요 자동장착 계속 눌러도 좋은것장착안되고 그것만 잘되면 별점 5개줄텐데.. 일일이 손수 좋은걸로 바꿔 껴야하니 번거롭네요;;',
#  '단순한데 재밌습니다.',
#  '업데이트 이후 앱실행이 안되요 지웠다 새로 깔아도 안되는데 어떻게 하죠?',
#  '과금유도도 적당하고 캐주얼하게 즐길수 있는 좋은 게임인것같습니다 다만 간혹가다가 스킬 발동이 버그처럼 지정된 곳에 발동이 안될때가 있어서 아쉬워요',
#  '하 게임도 재밌고 스토리도 참신해서 정말 강추 하고 싶지만 너무 현질유도게임 같습니다 보스도 깨기 정말힘들고 광산맵은 초월급입니다 아직 깰곳도 많이남아있는데 이 불편함을 해소좀 해주시면 정말좋을것같습니다 저는 지금 그것때문에스트레스생겨 지워버렸습니다',
#  '좋은데 무과금분들은 다 깨기 힘들것 같아요 난이도를 조금 쉽게 하면 좋을것 같아요! 그래도 재미있었어요!!!!!',
#  '솔직히 재미는 있는데 현질 안 하면 템도 좋은 거 잘 안 뜨고 캐릭터도 안 떠서 더 이상 진도를 못 나가겠음;; 이거 진짜 캐릭터 하나씩 주거나 확률을 높여주시거나 맵 난이도 좀 하향 시켜 주세요 ㅠㅠ 진짜 오랜만에 모바일 게임중에 재밌는거 겨유 찾았는데...',
#  '전투를 할때 화면이 까맣게 나오고 중간중간에 자꾸만 나가집니다. 이런버그를 고쳐주셨으면 좋겠습니다',
#  '광고, 렉 등이 적절하고, 그래픽도 아주 좋고, 밸런스도 괜찮고, 획득 보상 진짜 괜찮은거 같네요ㅎㅎ 진짜 추천드립니다. 지금까지 한 닌자 게임 중 제일 좋은 것 같네요ㅎ',
#  '개인적으로 이게임이 좋긴한데 옷 확률이 좀 낮다고 생각합니다. 그래도 게임은 잘 즐기고 있어서 재미는 최고인데 단 옷 확률이 좀 낮다는 점을 높게 올려주면 감사하겠습니다 그래도 게임은 재밌어요!!',
#  '진짜 제 인생 게임 입니다 앞으로도 야무진게임 만들어주십쇼',
#  '광고처럼 게임이 뻔하지 않고 fun하네요 만족합니다. 생각보다 퀄리티가 매우 좋았어요. 액션도.. 크으으으으... 굳굳 강추강추!! 그리고 이 게임이 나루토를 바탕으로 한것같은데 나루토 팬으로써 아주 좋아요. 캐릭터 예를들면 .. 츠나데! 그리고 속성들은 화둔,수둔,목둔,토둔, 환술! 환술은 윤회안?을 바탕으로한것 같고 체술은 분신술, 팔문둔갑 등등 잘 표현한 것같아요 .',
#  '정말 재미있는데 가끔 한번씩 미션 깨고 결과창 나와야하는 로딩중에서 화면이 멈추는 현상이 있네요',
#  '재밌긴한데 너무 캐릭터가 안움직이니까 재미가 사라지고 영혼석 채워지는 시간이 너무 느려서 다른게임하다 질려서 안하는경우가 있어 말씀드립니다',
#  '렉인건가요... 첫 시작부터 삐그덕.... 닉네임 지을려는데 화면이 반응이없네여... 키패드도 안뜨고 한번 겨우 밑에 키패드뜨면 잠깐있다가 사라지고... 이거 원 시작부터 힘드네여 패치좀...',
#  '네 3일동안 재미있게 하고 있는 유저입니다!이 게임 갓겜아고 정말 재미있어서 하고 있는데요...하지만 난이도가 너무 어려운것 같아서요......난이도 빼고는 다 좋은데...난이도를 좀 쉽게 바꾸실수는 없을까요..?',
#  '이 게임 정말 재미있어요!!!근데 성부터 좀 어려워요;;성-7겨우 깨고 성-8했는데 이건 너무 어렵네요 밸런스 패치좀 해주세요 리뷰보니까 밸런스 패치하라고 좀 있는데 빨리 해주시면 감사하겠습니다 너무 어렵지만 않으면 별 5개 넘게 주고싶은데....너무 성 스테이지가 어렵네요;;',
#  '가끔가다 순수대련에서 담장체력이 어마무시하게 올라가는 버그가 생기네요;;;',
#  '다 좋은데 도중에 에러 뜨는것만 고쳐줬으면 좋겠어요',
#  '대처가 빠르시네요 겜도 재밌고 아주 굿',
#  '제가보기엔 인술 체술 환술 다양하고 거기안에 스킬이 많아 재미있고 몬스터들도 다양ㅇ해 굉장히 재밌어요 다만아쉬운 점이 쉽게가다 갑자기 어려워지는 부분이 있습니다',
#  '닌자대전 재밌게 하다가 패키지 상품 구매했는데요 스테이지 클리어 하면 주는 보석 패키지인데, 초원에서 성까지 이미 깨고 배 스테이지 클리어중인데 스테이지 클리어 패키지 1 을 방금 구매하였습니다. 그런데 이미 클리어한 이용자가 이 상품을 구매했을 경우 이미 클리어했기때문에 3800여개의 보석을 수령할 수 있을 줄 알았는데 그게 아니더라구요. 그래서 기존 640개 정도만 수령했습니다. 환불 가능한가요? 받았던 보석은 사용하지않았습니다.',
#  '꽤나 신경써서 잘만든 영웅 수집형, 성장형, 디펜스 게임 과금없이도 상당부분 즐길 수 있다. 강제 광고보기 없음.',
#  '이겜이 갓겜인이유 1.디펜스게임을 하면서 기술을강화하고 하는맛이 있음2.캐릭터 마다 개성있음 3.토둔,화둔,목둔,수둔 이렇게 4가지하고도 체술,환술 이있어 굉장히 조합하는맛이있음',
#  '샤오미 포코폰 사용중입니다. 광고를 하나 보면 다음 광고를 볼 수 없고 준비중이라고 떠 광고 오류로 게임 진행이 안되네요. 업데이트시 참고 부탁드립니다.',
#  '노가다가 심하긴하지만 그래도 무과금으로도 충분히 즐길수있고 정해진길이 아닌 자신만의 스킬 아이템을 사용해서 쓸수있어 재밌습니다.',
#  '정말 재미는 있는 게임입니다. 하지만 이번 업데이트 이후 제 휴대폰에서 실행조차 되지않네요. 기종이 그렇게낮은 폰은 아닙니다.',
#  '게임을 접속할때마다 갑자기 홈 홈화면으로 튕깁나다. 보수해주셨으면 좋게습나다.',
#  '업데이트 후 어플 안켜집니다. 삭제 후 재설치 해도 안켜집니다. 시작한지 3일정도됐고 현질도 10만원정도했는데, 너무 화나네요.',
#  '재밌게 게임하고 있는 유저인데 갑자기 게임 접속이 안되네요 계속 눌러도 게임이 켜지지 않고 나가져요. 삭제했다가 다시 깔아도 계속 안들어가지네요.',
#  '너무 재밌어요!😀😀 그런데 성 부터는 난이도가 너무 높아서 클리어 하기 너무 힘드네요😭😭 조금만 난이도를 낮춰주시면 좋겠어요! 꼭좀 부탁드릴게요 😁😁',
#  '제가 이게임 정말좋아하지만 컨텐스는 추가되지 않고 시간이 지날수룩 점점 노동 게임처럼 되어가고 요괴중 물론 제가 약한것도 있지만 원거리에서 물 쏘는 그 요괴는 정말 비정상적으로 높은 방어력,체력,공격력을 가지고 있어 큰 스킬을 사용하면 요괴피가 없어지는 재미등으로 이 게임을 하는데 그 요괴가 나오면 스트레스가 납니다 꼭 그 요괴는 너프부탁드립니다 그리고 닌자랑 스킬 추가해 주셨으면 좋겠습니다 스킬 폭이 작아 대부분 유저들이 스킬을 1~2차이 정도 밖에 안납니다 그리고 누가봐도 쓰레기인 스킬은 안쓰구요 제 생각에는 그 스킬을 없애고 그 비슷한 좋은 스킬로 계선해주시면 감사하겠습니디',
#  '안녕하세요 재밌게 플레이하고 있습니다. 다름이 아니라 제가 3만7천원패키지 1+1실속패키지를 구매하였는데 출금은 되고 패키지가 안들어오네요. 조속히 확인 후 패키지지급해주시기 바랍니다',
#  '너무 재미있게하고있습니다. 영혼석 수급이라던지 영혼가루수급정도 조금 어려운부분을 수정 조금만 해주셔도 괜찮을것같습니다 감사합니다',
#  '나는 성장하는게 눈에 보여 재미있으나 단점은 낮은 현질 효율, 매우 많은 노가다, 꽤나 욕먹고 있는 운영이있어 별 4점 드리겠습니다',
#  '재미있긴 한데 스테이지를 올라갈 때마다 난이도가 너무 어려워 지는것 같아요 무기도 못얻어서 강해지지도 못하겠는데 적들은 한마리도 안죽고...좀 짜증나기도 하고 재미도 없어지는데 벨런스 조정좀 해주시면 안됄까요 진짜 못올라감..',
#  '잼나게 하고 있어요 그런데! 자동 전투 이넌겋이 있으면 레벨 올리기도 편할텐데 무조건 노가다늘 해야하는점이 좀 번거로운것 같아요 ㅠ',
#  '이....게임... 진짜 재밌어요.. 그래픽도 좋고 해서... 다음 업데이트 때 더 많은 닌자 기술과 기술의 임펙트를 더 살렸으면......레알 갓겜!!!!!!',
#  '광고없구 더빙깔끔하고 그래픽 스무스하고 스토리 개연성 완벽하다곤 할순없지만 무료게임이 이정도 퀄리티인건 처음봅니다 재밌어요',
#  '재밌네요 ㅎㅎ 소통만 잘 되면 갓겜될 듯 합니다.',
#  '게임자체는 굉장히재밌습니다. 특히 스킬이 시원하게 나가니 보는맛도있고 타격감도 느껴져서 좋았습니다. 앞으로 이런게임들이 더욱 많아졌으면 좋겠네요,',
#  '단 한번도 게임에 평점같은거 남긴적없다 이 게임 하지마라 ?같은 게임임 막히는거 뚫으려고 여기 리뷰에 나와있듯이 그 비싼 패키지들 현질했는데 결과는 결제한날부터 4일 지났는데도 전혀 진척없이 막힌구간에서 똑같이 되풀이 중인데다가 강해졌다는 느낌도 없고 전투력도 별로 안올라감 성능의 결함 문제로 환불 신청한것도 거부 당한다. 처음은 그냥저냥 할만한데 절대로 이 게임에 결제같은거 하지마라 돈 쓰레기통에 버리는거랑 똑같으니까',
#  '템이든 캐릭이든 나온거 또 나오고, 또 나오고. 스테이지는 어느 순간 어려워져서 진행이 안되고.. 너희가 그렇게 나오면 난 겜을 지운다. ㅃㅃ2',
#  '재밌습니다,꼭 해보시길 권하고 캐릭터도 다양하고 성장도 그렇게 느린 편도 아니라 진도가 쭉쭉 나가서 좋습니다!!',
#  '게임은 다양한 술법과 스테이지 단순하고 그래픽이 아기자기해서 좋은데 요괴들 공격력이 너무 강하네요 밸런스 패치를 하셔야 할 것 같습니다',
#  '과금안하면 힘들긴 하지만 공식카페보면서 하나하나 맞춰 키우고 하는 재미가 한시라도 눈을 땔수없을정도 입니다.근데 중요한건 하는현질하던 안하던 하는만큼 성장하고 장비 용병셋팅 카페공략만보고 잘따라하시면 무조건 빠르게 성장할수 있습니다.!!!',
#  '나루토에서 영감을 얻으신거 같은데 나루토 팬으로서 개인적으로 너무 게임 재밌게 잘 만드신듯 합니다 조작도 간편하고 시스템도 단순하고 캐릭터들고 귀염뽀짝해서 좋습니다 다만 인술을 더불어 체술과 환술의 기술추가 업데이트 해주시면 좋겠습니다',
#  '재미는 있음. 근데 진짜 저장 기능이 없나 잠깐 하다가 카톡와서 답장하고 다시할라고 하면 또 드럽게 긴 로딩 기다려야 함. 로딩시간이 짧은것도 절대 아니고, 일단 나중에 재밌으면 5점으로 다시 올릴건데 지금은 개빡쳐서 1점담',
#  '초반인 유저입니다. 처음에는 다른게임이랑 비슷하고 재미없네 이생각을 했습니다. 하지만 계속하다보니 다른게임과 다른 재미를 느꼇습니다 이 게임이 다른 여러 사람들한테 알려지면 좋겠군요.',
#  '성9 깬기념!! 던전 입장 재료 수급이 어려워서 오래..걸렸슴다 ㅜㅜ 다른 컨텐츠 도입되면 더욱 재밌어 질거 같아요!! 입장재료 기다리는동안..',
#  '정말재미있습니다 무과금인데도 2주정도하니 스펙도 어느정도 올라가고 좋은템도 조금노동하면 얻을수있으니 아쉬운건 컨텐츠가 적어서 게임플레이시간이 좀적어지네요.. 할게많아지면 조금더 재미있을텐뎅..',
#  '게임은 정말 잘만들었습니다. 근데 너무 자주 화면이 멈춰서 게임을 할수가 없어요... 게임은 진행중인데 화면이 안나와요 그래서 5분단위로 껐다켜야해요...',
#  '게임성이나 다 괜찬은데 게임 종료 메뉴가 없는게 너무 불편하내요 홈버튼으로 나가서 삭제 안하면 백그라운드에서 계속 실행중이고 종료메뉴를 좀 만들어주세요',
#  '5개월정도 됬으며 현질 월10만정도 한것같습니다 일단 현질없음 안되는 구조로 만들었습니다 공식카페(네이버)가 있는데 초기유저부터 신규 유저까지 두루있구요 결국 과금많이하는 핵과금유저중심으로 피드백및 업뎃이 이루어집니다 절대로 혈질없이 즐길수없는겜입니다 광고 현질유도가 지나칩니다 게임은 괜찮지만 그게 아쉽습니다',
#  '처음깔아보는데 너무 재미있게하고있습니다 캐릭터 하나하나의 개성이랑 성격도있고 튜토리얼도 재밌네요',
#  '무엇보다 광고랑 똑같아서 좋네요 요새 광고랑 다른게임이 너무 많아서 짜증낫는데.. 이건 광고 보는것도 선택사항이고 과금유도도 아직까진 괜찮고 재밋고 좋아요',
#  '초반에 술법하나 마음대로 샀다고 게임이진행이 안 되네요.돈벌려고 갈려해도 안 넘어가고 정말 너무 버그도 없고 재밌네요. 별점1점 드립니다.',
#  '굉장히 재미있어서 막 계속 하고 싶은데요, 영혼석이 부족하면 스토리 진행을 못한다는게 조금 아쉽네요 그래도 재밌어요 꿀잼',
#  '대전에 알맞은 레벨과 전투로 해주세요. 저보다 몇배로 넘은 레벨과 하니깐 겨우 하급닌자로 합니다. 그렇니 알맞은 대전을 해주시길바래요.',
#  '무슨 2주 했는데 들어가니 초기화인지 빽섭인지 초원 2단계로 가져있고 결제한거 다 사라지고 문의하니 스크린샷 찍어야 복구 된다하고 이미 없어진걸 어떻게 스크린샷을 찍어야 되는지 참 환불해달라니까 답변은 오지도 않고 그냥 새로 키운다고 결제한만큼 패키지 다시 넣어달라니까 답변없고 사기꾼이세요?',
#  '재미는 있는데 코스튬이 다양해봤자 뒷통수만 보여서 의미없네요. 캐릭터들이 위로가서 정면을 보여줬어야하는거 아닌가 싶습니다.',
#  '생각보다 재밌네요 무과금 유저도 시간을 들이면 광고를 통해서 아이템을 얻을 수 있네요 ㅎㅎ(시간이 오래걸리겠지만...) 초반에 튜토리얼도 좋고 중독되는 맛이 있네요ㅋㅋ 근데 영혼석은 좀 많이 얻고싶어요ㅜㅜ',
#  '저는이게임너무재미있게하고있는한유저입니다 하나부탁드릴게있는데게임을하다가몬스터수가얼마나남앗는지몰라서스킬을막쓰다가젔어요. 게임을하면서몬스터가몇마리남앗는지표시를해주셨으면좋겄습니다. 감사합니다.',
#  '재밌게 하고 현질도 많이했는데 자꾸 오류코드뜨면서 꺼저요....참...오류 코드로 어떻게 하라는건진 모르지만...현질한거 돌려달라고 하고싶은정도로 열심히하면 할수록 걍 게임이 멈춤ㅡㅡ',
#  '하루정도 재밌는 게임. 반복요소는 많지만 오토가 없음. 오토가 없을거면 반복요소가 적던자 아니면 반복이 재밌던지.. 이 게임하다 계속 졸아서 겜지움',
#  '조작법은 간단한데 쉽지는 않네요ㅎㅎ 그래픽 퀄리티도 매우 높고 재밌어서 5점 드립니다!!',
#  '재밌는데 조금더 컨텐츠를 만들어주세요! 맵도 확장해주시구요~ 특히 길드는 좋은데 그 뭐냐 길드끼리 채팅방이라던가 이런게 없어서 아쉬워여 게임은 재밌습니다',
#  '업적같은거도 생기면좋겠고 아이템창에서 팔거나 강화재료로쓰고싶은데 같은아이템 다른덱에도 쓰고있는경우도있어서 착용일괄해제 기능도 추가해주시면 좋겠습니당',
#  '게임자체는 재미있고 처음에는 빠져서 몇시간동안 붙잡고 했지만 급격하게 강해지는 몬스터들과 그들을 따라가지 못하는 나를 보니 재미가 반감됩니다. 한달정도는 할 생각으로 보통 과금하는데 제일 빨리 질려버린 케이스.',
#  '동기화기능이 없는거 같구요. 현질유도 심하네요. 그리고 페북동기화 기능도 없네요.',
#  '정말제미잏습니다 액션도보여주며 퍼즐처럼 조합하고 다만 성단계의 성-6단계가 깨기힘들기때문에 성12345에서 금패말고 보석을 더주는것이 좋을것같습니다 게임은 참 재미있게 플래이하고있습니다 제작자님응원합니다~~~~~~~!',
#  '1주일정도는 진짜 엄청 재밌고 점점 노가다가 늘어나서 지루해집니다. 끈기 있는사람에게 추천. 게임은 정말 쉽고 간단합니다',
#  '재밌게 하고있었는데 어제부터 갑자기 한판 할때마다 무한 로딩현상때문에 진행이 안되네요.... 한핀 완료 처리도안되서 보상도 못받고 개선 부탁드려요ㅠㅠㅠ 플레이가 안되니 영혼석도 못쓰고 뭐 할 수 있는게 없네요',
#  '진짜로 저한텐 거의 완벽한데요 별점을 4점 준 이유가 너무 영웅나오는 확률이 너무 낮아서 그 점빼서 별점 4점을 드렸습니다 4성이나 5성영웅을 얻을 확률을 높혀주세요',
#  '이런방식의 게임을 싫어하던 저도 좋아하게 되었습니다. 캐릭터가 너무 귀엽고 화둔! 수둔! 목둔! 토둔! 하는게 신기했습니다. 이펙트도 화려하고 타격감도 좋습니다. 이런 게임 만들어주셔서 감사합니다!',
#  '너무너무 재미있고 스킬쓰면서 나루토 손동작 안한사람 없제???ㅋ',
#  '제가 예전에 하던 게임인데 폰을 아이폰으로 바꾸고나서 계속 32/32가 다 차고 로딩하면 거기서 계속 튕깁니다.... 제폰으론 리뷰가 안돼서 전폰으로 해봅니다................... 고쳐주셨으면 하네요',
#  '진짜 내가만들어도 니보단 잘만듬',
#  '재밌네요 업데이트도 계속하시는거같고 . 건의는 가성비좀 좋은 현질세트 만들어주세용.저같은 소과금러는 가성비만봅니더 ..',
#  '약관에 어뷰징 유저 정지 시킨다고 명시해 놓고 일 터지니 이런일이 처음이다. 라며 과금유저들 정지 안 시키는 게임. 별 하나도 아깝다',
#  '해보시면 아시겠지만 처음해보면 살짝어려운느낌은 있지만 그래서그런지 하나하나깨는맛이 있고 기대이상으로 잘만들어진. 짜임새있는 모바일게임입니다',
#  '맵 중간중간 어려운 맵이 있는건 어느정도 이해는 하겠는데 순수대련때 상대를 바꿔도 계속 같은 상대 나오는거랑 저보다 전투력 2~3만 정도 낮은 상대 한테 지는건 좀 심하지 않나요?',
#  '어느순간부턴 돈독이 올랐는지 유저들 의견 묻지도않고 자꾸 쓸데없는테마를 만들어서 과금유도와 정신없게 겜의 노예로 만들려는게 눈에 보이기 시작했다 덕분에 미련없이 접을수있게됐다 이정도면 겜을 즐기는 단계가 아니라 강제노역을 당하는거다 카페는 유저와 최소한의 소통도 하지않으니 답답해서 마음이 썩어죽는사람들의 불만만 터지고 있고 더이상은 추천할수 없는 게임이다',
#  '정말재밋는 게임 개발진모두다 힘내세요!! 업데이트과정에 오류도있지만 3달쩨재밋게하고있습니다.',
#  '자동술법시전 업데이트 이후 몇몇스킬이 제대로 작동이 안되는 버그가 있습니다. 빠른시일내에 처리해주시길 바랍니다.',
#  '갤s9+ 인데 뭐만하면튕기고 1분동안 보스다잡아놔도 튕기고 스테이지깨다가 멈추고, 시간날려먹는게임. 그거 개선안하면 현질 받을생각은 하지도마세요..',
#  '재밋고 다 좋은데 업데트 좀 빨리해줬으면 합니다 새로운 맵그이랑 몹이랑 캐릭터랑 그리고 신규스킬도 기대하고 있습니다 빠른업뎃부탁 드립니다 별5개 드립니다',
#  '게임은 재미있는데 난이도가 무슨 와..... 그리고 이런 미친 난이도에 시간 제한 있는건 좀 아닌 것 같습니다.. 시간 제한을 좀 늘려 주시던지 아님 난이도 조절 좀 부탁드립니다 게임은 정말 재밌어요',
#  '스토리도 있고, 스테이지도 있고, pvp도 있고 개인적으로 재밌는 게임입니다. 이것말고도 컨텐츠가 많아요. 한번 해 보시는걸 추천합니다^^b',
#  '재미있음 추천추천',
#  '암 생각 없이 다운 받았는데 개존잼',
#  '여러가지의 인술을 사용할수있어서 좋고재밌는데 인술 쿨타임이 길고인술4개는 좀적은 거같아서 6칸정도로 늘리면더 재밌겠네요^^~!',
#  '너무 제미있고 잘만들었는데 자동 술법 시전을 좀더 정교하게 쓰게 해주세요 그리고 클릭하는 곳을 교정하게그대로 클릭 해주는 자동기능을 만들어 주세요!',
#  '날이 갈 수록 튕기는 빈도가 늘어만 가네요. 접속중에 튕기고 게임 중에 튕기고 보상창에서 광고 누르면 튕기고 광고 보는 중에 튕기고 광고 끝나면 튕기고 저만 그런건 가요. 폰 기종은 s9입니다.',
#  '너무 재밌어요!! 기술도 다양하고 캐릭터도 다양해서 좋아요!!근데 동료 스킬도 제가 정할 수 있으면 좋겠어요!!!',
#  '광고준비를 일부러안하시는건지 한번도전하고 보상받으면 끝나는 보스전에서 광고준비가 안됐다고 30분을기다려도 그대로네요...',
#  '게임이 재밌긴 하지만 너무 어렵고 한 스테이지 하고 다음 스테이지 가면 막혀요.그리고 겨우 깨는개 아니고 아에 못깸니다.또 있는데 황금 화패가 돌림판에서 너무 안나와요.확률좀 올려주세요. 이상 입니다.',
#  '이겜은 키우기게임 대충룰 알면 편히 할수있고 순식간에 고수가 될수있어요. 찐짜찐으로 추천',
#  '웬만해선 게임에서 광고안 보는데 이건 너무 재밌어서 광고를 봐야한다... 근데 요즘은 왜 항상 광고준비중인가요...',
#  '스킬창이 다양하긴한데 스킬이 돌,불,물,풀이 있어요 그런데 스킬이 가로로 네개 세로로네개라서 좀 아쉬어요 게임은 다좋고 재미있어요 근데 스킬좀 늘려주셨으면 좋겠습니당',
#  '6개월넘게 즐긴유저입니다. 계정에 문제가생겨 캐릭터가 사라졌음에도 사흘뒤까지 아무런 조취도 없고 원인도 밝혀내지못하고 복구만 해줄수있다는 답변이후 메일조차 쌩까는 그런 게임사.',
#  '일단 평타는 의미가 없다. 결국 숙련도나 컨트롤이 필요없고 그냥 스킬 난사로 몹 잡아야하는데 스킬은 장비빨로 데미지 올려야되서 의미가 없다. 결국 한시간짜리 게임이라는 뜻',
#  '게임진짜 전략적으로 잘마 신듯 하네요 ㅎㅎ 템드랍율만 쫌 올려주시면 더 재밌고 무과금으로도 충분히 할수 있을거 같네요!!',
#  '업데이트좀 많이 하고 이벤트점.. 재밌는겜인데 관리가 아직 덜된ㄴ느낌 그래도 나름 열심히 노가다로 즐기는 재밌지만 좀만 더 노력하면 진짜 갓겜 될수도.. 예전 서머너즈워 만큼은 되지않을까',
#  '무기파는 기능 넣으면 좋겠어요 안그러면 무기 아이템이 많아저서 꽉차서 못해요 그리고 무기많아지면 또 무기업그레이드 해야되서 돈이않싸아저요 그래서 지금 무기많아저서 게임 진행이안되요 다음 업데이트때 제발 부탁 드림니다',
#  '게임 로딩 후 시작된 소리는 되는디 화면이 안나옴. 보스몬스터도 그림자만 보임. 업뎃 후 오류인듯',
#  '뒤로 갈수록 상당히 어려운 면이 있긴 하지만 그래도 보상도 많고 재미도 있어서 4점 드립니다.',
#  '스킬사용하면 멈칫하면서 발동되는게 좀 아싑네요. 몹은 멈추지않고 흘러가면서 스킬이 들어가도록 했으면 좋겠어요.',
#  '재미있어요 1루만에 20단계나 갔어요정말로 재미 있어요! 이게임 추천 드려요 ♥이 게임 만드신분 유트브 에서 나와도 될것같은 느낌이 드네요 업데이트 만이 해주시고 다른 게임도 많이 만들어 주시고 나중에 유트브 가 되면 인기가 많을수도 있어요 다시 말합지만 업데이트 많이 해주시고 사랑해 주세요 이 게임 친구들 한테 재미 있다고 말해서 인기를 끌어 보고 다음단게를 많이 클리어 할게요!!!!!♥★ 👍👍👍👍👍👍👍👍👍👍정 말로 재미 있어요!이렇게 재미 있는 게임은 이거 에요 배그도 재밌지만 이게임도 재미있어요! 앞으로 더 힘내시고건강 하세요♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥(하트가 많을정도로 재미있음)★★♥♥★★♥이게임 유트브에 나와도 될정도고 김블루가 이게임 했으면 좋겠네요 거짓말 아니고 진짜 재미있어요♥♥♥♥',
#  '아니 로딩까지는 잘되는데 처음 로딩 다 끝나니깐 나가지는거임 그래서 다시 들어가서 로딩하고 할려니깐 또 나가지고5번을 했는데 안됩니다 하..재미있어보여서 할라했는데 진짜 빡치네요 이것땜에 하고싶은 마음도 없어져 버렸습니다 빨리좀 고쳐주면 좋겠습니다.',
#  '다좋은데 업적같은것도 만들어주시면 좋겠어요 예를들어 뭐 5성짜리 캐릭터 5개를 모으면 골드나 보석을준다. 이런 미션들을 만들면 스토리깨는것 말고도 목표가 생기지않을까요?',
#  '게임 자체는 진짜 핵꿀잼 하지만 현질 하지 않으면 성장시키기가 너무 힘드네요 그래도 지금 열심히 플레이 하고 있습니다 앞으로도 업데이트 많이 해주세요^^ 아 그리고 온라인 대전도 추가해시면 감사하겠습니다',
#  '조금하다가 팅기고 조금하다가 팅김. 게임자체는 좋은데 이거는 고치면 좋을듯 계속 팅기니까 하기싫고 스테이지 진행이 힘듬',
#  '패치이후 pvp누적보상되고나서 벨러스가 안맞아요. 전투력이 3만 이하인사람들은 매칭이 10만이상잡히고 누적은 커녕 기분만 잡치는데 어느정도 벨런스는 맞춰서 매칭되어야하는거 아닌가요',
#  '게임 자체눈 굉장히 단순하고 재미있습니다 하지만 마지막의 원숭이 보스 단계는 무과금유저들이 깨지 못할 정도로 스태이지를 만들어 놓으신거 같습니다 이점 외에는 좋은 게임인 것 같습니다',
#  '제작자님......왜 성-8만고치고 성-9는왜 안고쳤어요? 또이겼는데 졌다고 뜨네요 5일동안 안고쳐주시면 이게임 그만둘래요 요즘버그덕분에 게임이다막혔어요 그래서 할것도없어서 요즘자주 안해요 고쳐주시면 매일매일 이게임 할게요 (1년차 유저가) 그런데 환술이랑체술쓰니까 버그가 시작됐어요 성8이 어려워서 인술안쓰니까 버그나네요 다시인술써도 안먹히네요 제가무슨 핵이라도썼나요? 개짜증나네요 참았는데 그래도 성8은고쳐줘서 감사합니다 다른기능은괜찮은데 스토리만그러네요 이제하루남았어요',
#  '정말 재밌게 즐기고있습니다만 대전중 자꾸 게임이 멈추는현상이 발생합니다 그래서 종료하고 다시 시작해도 대전몇판안가 또멈춤니다 수정좀 부탁드리겠습니다',
#  '무과금으로도 충분히 재밌게 즐길 수 있긴 한데, 폰 기종에 따라 튕기는 경우가 많은 것 같네요. 그래도 나름 나족하고 있습니다.',
#  '게임은 재밌습니다 다만 초반에 이름 설정하는 것이 클릭이 안되더군요 확인 부탁드립니다 복사 붙여넣기해서 어렵게 가입했네요',
#  '게임은 재밌긴 한데..게임 자체의 특색은 조금 없는거 같네요. 어느 그 가슴이 웅장해 지는 만화에서 따온게 꽤나 많으신거 같습니다.',
#  '이거 장비 좋은거 드랍 확률 좀 올려주세요 제발요. 너무 화나서 스트레스 받아요 그니깐 제발좋은 장비 드랍 확률 좀 올려주세요 정말 힘들어서 그래요 출석체크 멘날 하고있는 데 시간이 너무 많이들어요.이벤트도 할려면 시간이 걸려서 그니깐 제발 좋은 장비 드랍 확률 좀 올려주세요.부틱할게요 제발♡',
#  '간단하고 재밌습니다. 현질은 하긴 했지만 이벤트라 5000원 정도였고 현질 안해도 되는게임 이라서 좋습니다',
#  '이거는 레알 갓겜이면서도 스킬쓰는 맛이있네욬ㅋㅋㅋㅋㅋ이거적들이 살살녹으니까 스트레스가 풀려요~~제가 해본게임중 가장 재밌는 게임이에요~~(╹◡╹)v꾸르잼~!!',
#  '아니.. 다른폰으로 소셜연동했는데 처음부터 다시키워져요 아이디좀 복구해죠요 모가몬 상황인지모르겟네... 빠르게복구좀요 메일도보냈어요',
#  '예전에 재밌게한 기억이 있어서 다시 깔아봤는데 계속 튕기네요 초반에는 그나마 덜 튕기다가 이제는 한판마다 튕기니 조금 고쳐주셨으면 좋겠습니다',
#  '게임은 재미있는데 알림올때마다 진동 3번울리는거 개별로예요.. 설정에가서 알림설정같은 것도 있었으면 좋겠어요.',
#  '재밌게 잘하던도중에 한번 서버연결에 실패하였다고 뜬 이후로 똑같이 뜨면서 아예 게임에 접속도안됩니다...',
#  '복귀 유저입니다 계속 로딩화면에서 계속 튕겨요 오랜만에 해보고 싶었는데...고쳐졌으면 합니다..',
#  '게임은 전체적으로 재밌는 편이나 최적화가 너무 안되있어서 렉도 자쥬걸리고 로딩시간이 무척 길어서 기다리다 지루해짐',
#  '몹들의 속성이 한눈에 알아볼수 있게 디자인 됐으면 좋겠습니다. 하나같이 흰색이니까 얘가 어떤 속성인지 헷갈릴때가 많아요',
#  '한번 해보기에는 매우 추천할만큼 재미있으나 후반에 골드와 장비노가다가 좀 거슬리는 요소가 된다 특히 장비노가다는 하면서 욕을 많이 할 것이다 신규 장비나오면 더욱 ㅋㅋ...',
#  '버그가 있네요..성 8라운드에서 체력 18남은 상태로 마지막 남은 애들다 죽였는데 게임 오버가 되네요 그 보스가 공격한적도 없는데 갑자기 죽으니까 당황스러네요;;계속 시도해보는데 똑같이 다 깨도 게임 오버를 당하네요 이점 고쳐주시면 5점 드리겠습니다 +고쳐졌네요☆ 감사합니다',
#  '이 닌자대전이라는게임은 5성캐를 쉽게얻을 수 있어1달채되지않은나도벌써4개가있지 이런점도좋지만 스테이지밀기가쉽고 스킬구현도짱짱좋아!! 다양성도있어!(스킬이) 한번깔아봐 엄청 재미있을걸?',
#  '아이템 획득이 좀 어려움.. 낮은 단계라도 템 확득이 쉬워졌음 좋겠고 초반 영혼석 소비가 너무 많아서 플레이타임자체를 넘 짧게 가져갈수밖에 없는게 아쉬움',
#  '수집형게임으로 재밌어요. 지루하다고 생각할 수 있지만, 스테이지를 깨기위한 스킬의 전략을 짜면서 지루함이 해결됩니다.',
#  '게임 난이도도 어렵진 않고 게임 한판 한판 끝날 때마다 보상이 많아서 좋네요',
#  '아직 초반이지만 쉬운 인터페이스에 귀여운 그림이 재밌네요. 가끔 말이 안맞는 대화가 조금;;',
#  '할거없음좋은데 처음엔 할만한데 가면갈수록 너무힘드네오 적당히힘들면좋은데 처음부터쉽다가 난이도가 갑자기 극상승해버리네요. 조금씩오르는것도아니고..',
#  '닌자대전 잠시 그만했다가 다시 복귀했는데요 다시 재미들였습니다. 옛날보다 늘어난 보상이랑 캐릭터로 매력을 느껴요. 너무 좋습니다. !!:)',
#  '좀 재밌어요 계속 하고 있어요 어찌보면 이 리뷰를 남긴다는게 게임을 어느스테이지까지는 했다는거고 재밌다는 방증 같아요 ㅎ 한번 깔아보시길권합니다 대충만든겜이 아니라서 해보실만해요',
#  '덕백 덕분에 스킬 연개도 가능하고 게임자체가 재밌음 할게임이 없을때하면 좋음 근데 나만그러는지 모르겠는데 로딩화면에서 18% 에서 약간 길게 멈춤 나머진다 좋음 ㅎㅎ',
#  '재미있고 쉽고 현질유도안되서 좋고 아이템도 잘나오고 죽으면 영석도 다시돌아오고 한마디로 재미있어요',
#  '캐쥬얼해서 좋은듯 아직 초반이라 스킬을 다는 못 쓰지만 다양성이 조금 부족해서 금방 질릴꺼 같긴합니다 그래도 간편한게임인건 확실 맛보기 추천',
#  '재미는있으나 광고가 너무많아요 또한 첫시작인데 광고제거비용에 투자하기 껄끄럽네요. 한달에 9900원은 첫유저에게 투자할만한가치인지 알수있는시간조차 애매합니다.',
#  '엄청 재밌어요! 처음에는 잘 안되는데 시간이 지날수록 더 잘해지니깐 재밌습니다 별1개주는 사람은 이해가 좀 안가긴하네요',
#  '게임은 재밌는데 장비나오는 확률이 좀... 확률 좀 올려주셨으면 좋겠습니다.그거 빼면 참 좋고 재밌는거 같아요!',
#  '엄청 재미있어요! 다양한 스킬도 있고 각 속성마다 스킬도 다양하고 닌자 뽑기 하는 맛도 있어요! 무과금으로도 전설 두루마리 얻기도 가능! 이게임 강추합니다',
#  '너무 재미있는데 ㅠㅠ 자꾸 게임만 키면 끊기고 렉 걸려서 게임을 못해요 삭제하고 다시 설치해도 같은 현상이네요 어찌 방법 없을까요',
#  '확실히 시간가는줄 모르고 플레이했고 업데이트를 빨리 해줬으면 좋겠습니다 3일만에 성9까지 깨고 하는일이 반복이되네여',
#  '게임 자체는 너무 재밌는데 중간에 너무 많이 튕겨요 그점 고치면 진짜 좋을거같음 그리고 튕기고 다시 들어갈때도 오래걸려서 별점 2점',
#  '이 게임 너무 재미있게 잘 하고 있습니다. 그런데 번개공격(뇌둔)이 있었으면 좋겠습니다. 너무 너무 재미있어요!',
#  '하루 진행 가능한게 한계가 잇는거 말고는 딱히 흠잡을게 없는데 요즘같은시대에... 예전 애니팡처럼 하트없이는 게임 못하는 그런 시스템을 한다는건...좀 그렇네요',
#  '큰과금없이 재미있게 하고 있습니다^^.다만 바라는 점이 있다면 두루마리 뽑기시 10+1같은 뽑기도 있었으면 좋겠다는 생각이 듭니다^^.',
#  '뭐지? 옛날엔 재미없어는데 지금은 엄청 재미있어요 그땐 너무 어려서 게임을 이해을 못했나? 그리고 저장이 잘 되었어요지웠져있다 깐건데 그때와 똑같은것 같아요',
#  '이게임 원시시대 게임이에요?? 수량 정해서 사는것도 없이 일일히 다클릭해야되네 100개면 100개를 손으로 일일히;;; 간단한 싱글게임도 수량정해서 사지는데 대단한게임인걸요?',
#  '오랜만에 복귀하려 했더니 로딩화면에서 튕기네요 예전부터 시도해왔는데 자꾸 튕겨요 많은 사람들이 리뷰로 고쳐달라고 얼마나 많이 달았는데 아직도 안 고칩니까? 예전엔 재미있었는데 실망입니다 게임듀오',
#  '친구가 추천해봐서 한번 해봤는데 진짜 재밌어요~~ 스킬도 멋있고 캐릭터들도 심플해서 좋네여 ㅎㅎ',
#  '재밎는데 제한시간과 체력이벨런스가좀그렇네요 보스는2분으로해주시고체력30%깎아주시면감사하게 게임을 하겟습니다.',
#  '재밌긴 엄청 재미있는데 능력이 너무 부족해요 무슨 말이냐면 능력의 개수가 너무 적어서 게임을 금방 삭제하게 되네요. 여러 스킬들을 추가해주세요.',
#  '너무너무 재미있게하고있어요 노가다는조금 힘들지만 하나바라는점이있어요 도감에 세트장비만 추가해주시면안되나요',
#  '오랜만에 할려그랬는데 로딩창에서 자꾸 튕겨요 저와 그리고 많은사람들이 복귀 할 수 있게 버그를 고쳐주셨으면 합니다',
#  '재밌긴한데 너무 반복되는 컨텐츠만 하다보니까 좀 질리네요. 재밌는 컨텐츠 하나 추가해주셨으면 합니다.',
#  '제가 이겜을 하고있는 유저인데요 게임에 접속하면 계속 에러가 떠요 이거좀 고쳐주세요 에러뜨는것 빼고는 다 괜챃습니ㅏ다ㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏ에러좀 고쳐수세요ㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛㅛ',
#  '컨트롤따위 필요치않고 게임수준대비 말도안되는 과금유도패키지가 많습니다. 또한 과금러위주의 업뎃밑 피드백이 이뤄지고요. 투자대비 만족도가 낮은 게임 입니다.',
#  '정말 재밌게 하고있습니다 근데 제가 마을을 만들었는데 실수로 활동하지 않는 사람한테 대장을 위임 시켰습니다 재화도 은근 채워서 얼른 마을원들한테 보상을 주고싶은데 제가 대장이 아니게 되어서 어찌할수가 없네요 그래서 다음 업데이트때 대장이나 마을원이 오랜시간동안 비활동을 할 시에 자동 퇴출되는 기능을 만들어주시면 좋겠습니다 제 마을을 꼭 다시 성장시키고 싶어서 간절합니다 부탁드립니다 개발자님',
#  '간단하게 할수있는 게임이여서 좋아요.그리고 어디서나 간편하게할수 있어어 너무 좋아요. 오랜만에 재미있는 게임을 찾아서 좋네요.ㅎㅎ',
#  '노가다성이 좀 잇지만 재미있습니다!!템조합 캐릭터조합 맞추면서 강해지는 재미가있어요!!',
#  '아직 20 스테이지 근처인데 그래픽도 아기자기하니 괜찮고 스킬쓰는 방식같은게 간단해서 아주 좋네요 시간도 살살 녹고 키우는 맛도 있는것 같아요',
#  '제가 현질했던 내역이 모두사라져 현제 혜택을 못받고있습니다,, 어느날은 되었다가 어는날은 안되고.. 다시 해주시던지 환불해주셔야할것같습니다..',
#  '재미있습니다 조작도 편리하고 근대 단점은 너무 난이도가 힘들어요',
#  "창에서 나가기 버튼(X)이 보이지 않아 게임을 껏다 켯다 합니다, 원래 없는 것이라면 '추가'하여 주시면 감사하겠습니다. (리뷰를 두개나 쓰네?)",
#  '정말 재밌고 현질유도 별로 없다 생각하는데 강화할때 목각 인형만 쓴다는게 너무 좀 힘듭니다 그것 외엔 정말 재밌습니다',
#  '현질을 해달라고 강요하지도 않고 게임 자체를 잘 만들어서 너무 인상 깊은 게임입니다.특히 성우님들 목소리가 너무 좋아서 이 게임을 맨날 하고 있습니다. 화이팅.',
#  '스킬 씹히는 오류들 각 컨텐츠마다 덱 따로 설정가능하게 편의성 개선 아이템 드랍확률개선 그렇게 카페서 욕먹고있는데 좀 고쳐라좀 오류가있으면 바로 수정해야할판에 몇주가 지났는데 공지도 없네',
#  '게임 자체는 재미있거든요? 노가다를 엄청 했는데도 못깨는 스테이지가 많습니다..스테이지가 너무 어려워요',
#  '스테이지가 넘어 갈때 마다 난이도가 너무 높아져요. 난이도 차이를 조금만 줄여주셨으면해요 다른건 너무 재밌네요',
#  '다좋은데 아이템드랍확률좀요. 무슨 5판연속 템이 안뜨면 문제가있는거죠. 카페에 공지로 좀 알려주세요. 아이템 뜰 확률좀요',
#  '그냥다 완벽한데??캐릭도 잘나오고 현질할때 약간에 돈이 드는 편이지만 캐릭 확율이 좋아 굳이 할필요도 없고...그냥 이게임이 좋아',
#  '처음에는 쉬워서 재미있었는데 조금 많이가니까 어려워요 그런데 그런걸 깨는 맛도있어서 재미있어요 인생최고의 게임이에요',
#  '그냥 한번 깔아봤는데 너무 재밌습니다!!! 여러가지 기술로 전략적이게 할 수 있어서 더 재밌네요!!',
#  '[1줄평]정말 최고입니다(따봉) [현재의]화려한 스킬 간z나는 음성! 킬링타임에 최고!그렇고도 심플해 눈아프지도않은 한마디로 갓☆겜 입니다. 오랜만에 게임성이 잘잡힌 갓겜님을 영접했내요 ㅎㅎ [앞으로의]더많은 스킬은 필수적이여야할거같아요. PVP정도는 추가해도 좋을거같아요(사실 제일 바라는거임 ㅎ)하지만 PVP를만든다면 어캐만들지 고민을많이하실탠디..(믿어요!)그렇다고 요일던전,뭐시기의 탑 같은건 재발 PLEASE NO 안됍니다 갓.겜을 망치는 지.름.길 이니까요(^~^) [갓.겜도 단점은 있다]사실 단점이라기보단 더낳은 게임을 위해..가 정답이겠죠 일단 모든게임의 문제 Money....과금요소는 앞으로의 업데이트를위해 점점 독해지지만 않았으면합니다(이것도 믿어요!) 그리고 성우분의 목소리가 너무좋았지만 스킬의 속성만 말하고 스킬이름을 안말하는게 아쉽내요 그리고 몇 가지 편의기능 정도..?예시로 모든케릭터의 장비를 한화면에서 드레그로 바꿀수있으면 좋겠내요 다시보니pvp있내..ㅎ',
#  '퀄리티 재미 다 있는데요 무과금으로 하기엔 너무 빡치네요 다 좋은데 사냥을 통한 노가다가 기회가 너무 적어서 딥빡입니다. 배14를 못넘고 하차 합니다',
#  '게임은 너무 재밌는데 성부터 무과금의 한계를느끼고 이건아니다 싶어서 삭제했습니다. 초반지원을 많이해주던가 밸런스패치가필요하다고 느낍니다',
#  '과금이 필요없는 개꿀잼 게임입니다 그래픽도 옛날 감성 나면서 튀지도 않으면서 좋네요 최고예요!',
#  '여러가지스킬 여러가지장비 컨텐츠 도 다양하구 정말 시각적으로 재밌고 성장 시켜가는재미도 잏고 다방면으로 만족합니다 개발자 님 스킬더 많이 만드실꺼죠?? 개꿀잼~',
#  '개재밌음 광고 보고 깔았는데 은근 중독성있고 엄~~청 어렵지도 않고 그렇다거 시시하지도 않고 단순해서 더 좋은거 같아요~',
#  '과금유도가 심한편이고 오류가 많고 유저에게 득이 된다면 오류수정 2시간 유저에게 불편한오류는 오류수정 2주일 따지면 단톡방 강퇴,카페영구추방.. 그것만빼면 잘만든 재미있는 게임입니다.',
#  '너무 혜자겜이고 구성도좋고 그냥 다좋아여 근데 난이도가 너무 어려워요ㅠㅠ 그리고 뽑기 확률좀 높여주세요ㅠ',
#  '안녕하세요. 닌자대전 재미지게 하고 있는 유저입니다. 흠...게임은 재밌는데요 대요괴 토벌에서 좀 뭐랄까 조금 아쉽습니다 원하는 템이 너무 안나와서요 장비 얻는거 말고는 딱히 저는 불만 사항이 없네요 그럼 고생하세요',
#  '너무 재밌게 하고 있는데... 업데이트가 중단되면서 게임 운영이 종료되는건 아닌지 걱정이네요 ㅠ',
#  '모두 다 좋고 재밌지만 영혼석이 차는 시간이 너무 느린감이 있어요 이것만 수정해주시면 완벽할것 같아요',
#  '갭 차이가 너무나 큼. 대전상대가 말도 안됨.투력 2만하고 2천만하고 상대를 붙이다니.. 매번 똑같아..',
#  '폰게임 하면서 처음으로 광고 봐도 안짜증나고 오히려 무료광고까지 찾아보게하는게임 그래픽 퀄도 매우 좋고 ui나 컨트롤도 만족 겜 재밌습니다',
#  '계속 시작하면 에러 뜨고 게임이 진행도 안되고 .. 고쳐질 기미도 안보이고 .. 재밌게 하는 유저인데 불편하네요 ..',
#  '겜이 안 들어가짐 play 게임 접속중 위에 떳다가 gameduo위에 로딩 중 동그랗게 돌아가고 접속이 안 됨. 진짜 20번정도 껐다 켰다 반복하다보면 한 번식 들어가짐 불편해죽겠습니다',
#  '신박하네요. 아직까진 재밌게 하고 있습니다. 그림체도 귀엽고, 스토리 설명 때 할아버지가 바짓속에서 아이템 꺼내는게 재밌어요.',
#  '초보자들도 쉽게할수있어서 좋네요 다만 스테이지깨는게너무힘드네요ㅋㅋ 요번업뎃도너무좋네요',
#  '주관적인 면으로 보면 게임 초반에는 조작플레이가 상당히 쉽고 진행도가 빨라서 흥미가 생깁니다. 하지만 후반부에 성9에서 말도 안돼는 게임밸런스 붕괴가 있더군요 게임 개발진들이 노린수 인지 아니면 개발진행을 덜하신건지 상당히 안타까운 점이였습니다 게임머니를 사고싶어도 너무 비싼가격에 성인인 직장인인 저도 저가격은 너무하다 생각이들어 사고싶지가 않더라구요 또한 가격자체를 높게 책정하신이유는 개발이덜된 게임을 급하게 내놓는라 그런느낌이강합니다. 하지만 개발자분들께서 알아야할점이 있습니다 기획에서 설계가 미스가 난것같습니다 게임시장을 좀더 조사해보시고 다른 타워디펜스등에 게임들이 어떤식으로 진행을 하는지를 좀더 살펴보시고 진행했더라면 이런 게임밸런스붕괴로 인해 사람들의 지갑을 열지 못한다고 생각이듭니다. 게임 ui 자체는 이해가 쉽고 부드럽게 넘어가나 심한밸런스붕괴로 안타까울뿐입니다. 좀더이런부분들을 개선해주신다면 지금보다더많은 이익과 고객층들을 더욱더 많이 확보하실 수 있으실겁니다.',
#  '너무 재밌고 안질린다는게 가장 신기함 무기나 장비 전설들이 간지나는데 그거얻으면 엄청 행복함 ㅋㅋ 그리고 밸런스도 좋은데 튜토리얼 설명이 좀긴듯...',
#  '개임에 본질은 너무좋습니다 아이디어도 좋구여 근데 강화 나 다음스테이지로 넘어갈때 자꾸 끊기네요 그래서 다시 시작해야 됬던게 한두번이 아닙니다 이 점 꼭 고쳐주세요 재밌어요',
#  '게임은 훌륭하지만 전체적인 운영이 아쉅네요 업뎃 자주하고 더 컨텐츠가 많다면 더 멋진 게임이 될것 같아요!',
#  '굉장히 재밌어요! 복잡한 조작이 필요없어 가지고 상당히 쉽고 재밌게 플레이가 가능해요!',
#  '너무제밌어요스토리도많고동료도많고저는다좋은데동료뽑는데동전같은게너무안나와서확률을올려주시면좋을것같아요',
#  '와이거대박이의요 아패는말이만치만 뒤의는대박이에요 동료를처음어드면 동료는할아버진데 돌을던저요ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜어여운것도있는데쉬워요잘하면ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 올!',
#  '로딩만하다가 계속 튕기는데? 전에는 안이랬던거 같은데 복귀하고나니 튕기기만하고 게임 1분조차도 못하고있음,,',
#  '이거 게임은 나름대로 재미있고 할만한데 자꾸 튕기네요 벌써 몇번째인지 오늘 튕거만 15번 100로넘구요 전원도 껐다켜보고 지웠다 다시깔았는데도 반복이네요 빨고쳐주세요.좀 실망입니다',
#  '엄청 재밌고 맵네요ㅋㅋㅋ 근데 비술 체험하기에서 요괴를 소환하는 기능도 있었으면 좋겠어요.',
#  '제가 세로게임 재밌는거 어디없나.. 라고 계속 찾고 있었는데 닌자대전이라는 게임을 찾음.진짜 재밌긴 한데 돈으로 화둔기술 샀는데 갑자기 에러가 떠서 다시 들어가 봤더니 돈만 없어지고 기술은 안사졌음..ㅠㅠ 이거 버그좀 고쳐주세요ㅠㅠ',
#  '디펜스게임 오랜만에 하는데 재미있어요 :) 평소 시간 많이 안 잡아먹고 가볍게 할 수 있어서 좋아요.',
#  '그림체도 재밌고 나쁘지 않아요! 상점창 같은 곳만 좀 더 편하게 변하면 좋겠어요 :)',
#  '참재미있네요 하지만 돈벌기가 참 어려워요ㅠㅠ 게임은 참 재미있는데 돈이나 아이템 엏기가 어려워서 힘드네요',
#  '진짜 게임은 재밌습니다. 근데 장비 초과치로 게임을 즐기지 못하고 있습니다. 장비합성을 추가해주시던지 장비판매를 추가해주세요 게임을 하고싶은데 못하고있는상황이네여',
#  '오랜만에 재미있는 게임하네요. 이렇게 재미있는게임 만들어주셔서 감사하고 앞으로도 닌자대전 재미있게 플레이할게요.',
#  '게임은너무 재미있습니다 ㅋㅋㅋ 근데 이번에 전설부적마리 개봉하다가 렉이 걸려서 껐다 켰는데....금전만 사라졌어요 해결 부탁드립니다',
#  '재미있어요근대착용하고있던거보다좋은게나와서교체하고팔려했는데자꾸댁에착용중인아이탬이라해서불편합니다빨리고쳐주시길바랍니다 이게임은갓겜이다',
#  '게임이너무너무재미있어서열심히하고있었습니다. 근데 이번업데이트후 아이템이 사라졌어요...확인부탁드립니다.',
#  '와우 정말 재미있어요 재가 한게임을 오래하지 못하는데도 이건 정말 오래 하고 있어요 그정도로 이게임 중독성이 좋고 보상도 후한것 같아요',
#  '방금 막 들어가려고 했는데 업데이트를 하라고 문구나오는데 들어가면 업데이트 할려면 업데트창이 안 떠서 못들어 가고 있어요',
#  '게임 잘만든거같아요 스토어에 뜨더라도 그냥 지나쳤는데 광고보고 국산게임인걸 알았네요 광고로 다량의 무료재화 습득이가능한것도 좋고 게임이 재밌네요',
#  '뭔가 모르게 잼있다. 근데 이벤트같은건 별로없는거 같다. 처음시작했는데 공략을 많이찾아보고 진행해야 할것 같다.',
#  '심심할 때 하면 재미있습니당.그리고 기술(?) 도 많이 업데이트 해주시면 좋겠습니다.',
#  '솔직히보스는좀어렵지만 엄청~~~재미있어요 다음업데이트때는 기술을 좀싸게해주세요그래도재미있고스릴있어요',
#  '저는 솔직히 이 게임이 왜 안뜨는지 모르겠네요 게임도 괜찮고 제가 만화를 좋아하는데 만화라서 좋고(개인) 캐릭터도 아주 아기자기 해서 너무X100 좋은것 같아요 아주아주아주아주 추천입니다 저는 이 게임 친구들한테 뿌리러 갑니다',
#  '보상받으려고광고보려할때는준비중이라그러고,한판끝내면광고가뜨고.좀고쳐줘요그리고유저수많은건개뿔딴겜에서는1억유저가있는데도잘돌아가는고만',
#  '정말 재밌는데 영혼석이 너무 부족합니다... 게임플레이를 하지못하니 성장이 너무 느려 답답합니다',
#  '게임은 너무 재미있습니다. 하지만 지금 Eorror가 뜨면서 들어가지지 않습니다. 해결해주셨으면 합니다.',
#  '진짜 퀄리티는 말할것도 없구요 진짜 레알 꿀잼!!! 믿고 해보시면 진짜 후회 안하실겁니다!(그만큼 엄청 재밌다는 뜻) 닌자대전 게임 찾은거는 유튜브 광고에서 봤다가 깔아봤는데 이렇게 재밌을줄은 몰랐어요 캐릭터 성우 분들도 엄청 연기 잘하심!!!이거 하면 1시간도 뚝딱 입니다...헥...헥...숨찬다.....헉.....꼭....해보시길!!!!',
#  '아직 뭔가 컨텐츠가 적은느낌이지만 그래도 처음할때는 그래픽도 귀엽고 캐쥬얼하게 즐기긴 좋은거같아요',
# ...
#  '내가 왠만해서는 4점이하인주는데 이건.... 난이도가 너무높아요 몬스터 대미지도 너무높고 원거리인애들이 집기가 너무힘들어요 채력도 뭔 10000이상인거같에요그렇다고좋은닌자 템이 막 니오는것이 아니잖아요 이거는 패치좀 해야됍니다',
#  '제가지금 배 5인가 하고있는데 너무 어려운거같아요 ㅠㅠ 근데 엄청 재밌어요!',
#  '문의 메일도 드렸는데 답장이 없으셔서 남겨요 아이폰에서 쓰던 계정 안드로이드로 이전 부탁드려요 곧 아이폰 반납해야돼서 얼른 이전해주셔야합니다.',
#  '정말 재밌고 스토리도 재밌고 그리고 깨는 맛이랑 키우는 맛이있어서 정말 재밌습니다 제작자 화이팅',
#  '간단하구 재밋네영 근데 스킬 연속으로쓸떼 가끔 데미지가 안들어가는것 같아요',
#  '게임음 재밌는데 그 토벌 식인 괴수목을 플레이 하는데 제 피가 다 달지 않았는데 제가 졌다며 메시지가 뜨는데 이거 버그인가요? 아님 제가 너무 약한건가요? 피가 6000이상 남아있었는데 난이도는 정예 1이였어요',
#  '마음속의 1순위게임',
#  '너무 재밌게 플레이합니다!!! 스킬도 다양하고 캐릭터도 귀엽고요^^',
#  '재미는 있는데 제발 들어갈 때 중간에 퍼센트 멈춰서 안 들어가지는 버그 좀 고쳐줘요',
#  '솔직히 재미있게 하고잇긴합니다 근데 불편한게 화면고정좀해주시면좋겟습다 자깜핸드폰 놔두면 자꾸꺼져서 불편해요',
#  '광고 도대체 뭐죠..? 안할수도 없고 하자니 1달 기간제이고 딱 광고 제거만 있고 돈벌기 싫으신가 좀 줄여주시거나 광고제거패키지를 이런식으로 팔지마세요 !!!',
#  '아직까지는 현질 유도 없이 재밌게 즐길 수 있는 게임입니다👍👍',
#  '정말재밌어요 근데 친구랑 배틀등등 많은 게임모드가 생기면 더 재밌을것 같아요^^',
#  '너무재밌습니다 근데 나중에 업데이트 할때 무기를 살수있게 현질멀고요 부탁드려요 제발요 제발 비나이다비나이다',
#  '정말 재미있습니다 여러가지 술법들이 있고 적에 상성에 맞춰서 하는게 재미있습니다',
#  '형이 재밌다재밌다해서 깔아봤는데 정말 재미있네요 술법열고 쎄지는걸 보는게 정말 좋네요',
#  '빡세다 너무 닌린이도 좀 빨리 올라갈수있게 다양하게 좀 도와주면 좋겠다',
#  '아이탬 한번에 팔기 기능이있음좋겠네요 그리고 보스몹 잡기 대전하기 한판 할때마다 나가지는거 말고 다시하기 만들어주세요',
#  '게임하다 갑자기 무한로딩 걸리고 껐다 들어가니 검은화면만 나오면서 암것도 안되네요 이겜은 그냥 거릅니다.',
#  '영자님 저 오류로 주인공캐릭터밖에 캐릭터가 안보이고 버튼이안늘려집니다 오류 어떻게 해결가능한가요?',
#  '재밌는데 자꾸 스테이지 후 무한로딩이 걸립니다. 보상해주새요',
#  '아주 싸발적인 게임. 2년전 부터 로딩창에서 안들어가지는게 지금까지 안고쳐?ㅋ',
#  '출시 초반에 알았었으면 진짜 재미있게 했을텐데... 좀 아쉬워요~',
#  '정말 재밌어요! 삭제 했다가 깔아도 저장이 되고 아주 재밌어요',
#  '완전 울트라 슈퍼 짱찡짱 갓띵작 입니다 완전 재미있게 플레이 했습니다 이런 게임을 만들어 주셔서 감사합니다',
#  '갓겜 재미있고 독특하다.조금 아쉬운 점은 멀티가 지원이 별로 안돼있다.',
#  '정말재미있어요 요즘 재미있는게임이 없는대 재미있는게임 찾으려고 스토어 둘러 보는대 이게임이 재미있어보여서깔고 해봤는대 정말 재미 있었습니다 개발자님 이게임 만들어 주셔서 정말 감사합니다',
#  '현질 유도도 심하지 않고 무과금으로도 재밌게 플레이 할수있다는게 너무 좋네요 ^^',
#  '계속버전이낮다라고합니다 삭제후 재설치했는데도 마찬가지네요',
#  '넌 진짜 몇달동안 계~속 남아있는 접속오류도 안 고치고 광고를 올려버리냐 ㅋㅋㅋㅋㅋㅋ',
#  '시간때우기로 좋네요 강제로 봐야하는 광고도 없고 할만해요',
#  '카페 공략보면서 하세요 무과금도 시간만들이면 충분히 합니다 재밌습니다',
#  '초반인데 아직 괜찮습니다. 재밌어요',
#  '야! 당장 깔아! 리얼존잼 심심할때하고 안심심할때하고 아무튼깔아! 장비모으는 재미도 있음 진짜존잼',
#  '이게임 재밌어서 3점 드리고요. 왜 스테이지를 깨면 아이템을 주는 스테이진데 왜 깼는데 안줘요?그거 고치면 5개 드립니다.',
#  '너무 스킬이 멋져요 그리고 제가 좋아하는 캐릭터 입니다 요즘 제가 너무 많이 하는 게임 입니다',
#  '딱히 할말 없음. 그냥 그럭저럭한 게임임. 아쉬운건 무과금으로 하면 좀 힘든것 뿐. 돈 쓰는게 나음',
#  '지루한 진행에 비해 보상이 적어 파밍이 매우 힘들다.',
#  '중요 재화를 얻는 방법이 광고와 현질이라 생각보다 키우는 속도가 더뎌요 참고하세요',
#  '이 게임은 모든게 완벽하고 재밌는게임입니다. 꼭 해보시길 추천해드릴게요',
#  '일단 광고없어서 좋고 단순하지만 머리를 사용해야해서 만점드립니다^^',
#  '아이 재밌어 아주그냥 이집 게임좀 알어~ 요세 내가 이거 때문에 잠을 못자 ㅎ 배터리도 너무나가~',
#  '아니 장난해요 처음 로딩때는5분이걸리고 로딩끝나서 닉넴정하라해서 닉넴을 정했는데 이번엔 중복됬데 참 이거뿐만아니 그래서 내가 다시들어가서 로딩을 기다리는데 야 무슨 컴배다운받어?아니10분이걸려 또니네들이첨에 들어갈때 지어주는이름으로 했는데 이런이름은 사용할수없데 아니 그럼 느그들은 왜 첨에시작하면 닉을 정해줘 돼지도않는걸 좀 일해라 이러니깐 다운자수가 이따구지 제대로 만들어들어가는데만10분이고 이름도 중복아님 할수없다하고 게임이? ㅋㅋㅋ웃음만나온다 정말 거지같은겜이여서',
#  '컴퓨터로 할려고 녹스로 로그인해서 햇는데 처음부터 시작되더니 원래 쓰던계정으로 안들어가지네요 새로만들어진 계정에 원래 닉네임쳤는데 닉네임있는걸로 떠요 해결방안좀요',
#  '다좋은데광산마지막에서버그가있네용제폰때문인지는모르겠지만그거빼고는다괞찮네요',
#  '게임이 시작할때 계속 팅기네요.. 게임은 재밌습니다',
#  '현재 업데이트를 하라고 해서 업데이트를 했는데 여전히 버젼이 낮다고 업데이트를 하라고 하네요 제거 후 다시 깔아도 그대로입니다. 뭐죠',
#  '들어가지도못하고 튕기기만합니다 전원을 껐다 켜도 계속 튕겨요',
#  '모바일게임중에 할거별로없는대 이렇게재밌는게임이 광고로나오니까 주체 아니 1의망서림도없이설치했다 너모재밌당^^',
#  '광고 한개를보면 다른광고는 광고준비중이라 뜨고 광고를 볼 수가없네요 하루에 볼 수있는 광고가 제한되어있나요?',
#  '와 너무 잼있고 하루만에 다깼고 스토리도 쏠쏠하고 캐릭터들도 멋있어서 5점 줍니다!',
#  '스테이지 할때 그냥좀 하게 해주세요 그리고 스킬도 더 만들어 주세요 그리고 운빨이 너무 심함니다',
#  '간만에 혜자스러운 갓겜 잘하고있습니다 운영진분들 피드백도 빠르고 너무좋습니다',
#  '버전이 낮아서 업데이트 하라고 하는데 가능한 업데이트가 없다고 나오네요 게임도 못하고 있는데;',
#  '스테이지 미는데 막히면 하루정도는 못밈 스테이지난이도 너무어려움.',
#  '재미있네요 아직상점시스템이 완전히갖추어지지않은것이아쉽네요 ㅎ',
#  '5월에 시작해서 한달에 광고제거만 결제하고 매우 만족스럽게 게임하고있습니다',
#  '저의 인생 최고의 갓겜입니다 게임을 싫어하시는 분들도 최소 1번은 해봐야함',
#  '재미있는데 성가면 너무 어려워짐 그리고 1초에 잡으면 실패로뜨는거 고쳐주세요 제발',
#  '제 약간의 시간중에 게임중에 즐겁게 즐겼습니다. 간단하게 하기좋네요.',
#  '다 재미 있는데 로딩 할때마다 로딩바가 렉이걸리거나 게임이 검은 화면으로 변해요...',
#  '재미는 있는데 와이파이가 필요해서 아쉽네요 그럼 갓겜 각 인정',
#  '걍 시간때우러 시작햇다가 잼써서 계속하는중입니다 ㅋㅋ 추천해여',
#  '다 좋은데요 렉걸리고 갑자기 게임 강종돼요ㅠㅠ그래도 재미있어서 4점 드려요 그리고 배7보스 피가 안단다..',
#  '업데이트만 빠르면 완벽한 게임.항상 재밌게하고있습니다 화이팅',
#  '간단해 보이지만 전략을 요구합니다. 은근 빠져드네요',
#  '아니 계속 로딩에서 팅기도 팅기고 계속 팅기니다 할려고하면 팅기니다 고쳐주세요',
#  '재밌음니다. ㅋㅋㅋ 광고가 제대로 안 봐져서 아쉽네요',
#  '어떡해 이런걸 광고까지 했을까... 제작비보다 광고 비용이 더 나왔겠네요',
#  '재미있어요 근데 계속 버그 지속 현상 이 됩니다 재발 버그 고쳐 주세요',
#  '이제 근 한달간 플레이 했는데요 특정 유닛의 요구도가 높은것 같아요.',
#  '아니 게임애 접속이않됩니다 게임을 껏다 켜도 게임을 업대이트를해도 와이파이가 좋아도 접속이 않됩니다 고처주세요',
#  '저 벌써 성7이에요! 이게임이 너무 재미있어서 항상 이게임 만해요. 그리고 술법도 전부다 모았어요. 체술,인술,환술 까지 다!',
#  '받았더니 업데이트 하라고만 뜨고 업데이트도 실행도 안됨',
#  '재밌긴하지만 노가다랑 현질 유도가 심하고 난이도 점체적으로 어려움',
#  '성 8이 더 어렵습니다. 성 7어려워하시는분들은 환술 두번째꺼 써보세요 쉬워요',
#  '가끔 와이파이상태인데 갑자기 네트워크오류가 뜰때가 있습니당',
#  '게임스토리와 그래픽 등 진짜 시간떼우거나 할거없으면 아고하기딱좋음',
#  '이거 왜 안뜨는지 모르겠음 ㅋㅋㅋㅋㅋㅋㅋ 빨리 질리긴하는데 또 지우고나면 막상 다시 하고싶어짐',
#  '재밌어 보이는데 깔고 들어갈때 마다 튕김 ㅡㅡ 깔아서 다시 해도 안됨.',
#  '계속 게임을 하는데 튕기네요 내폰이 문제인가? 싶어서 다른폰의로 해봤는데 계속 튕기네요 고쳐주십소',
#  '정말 흥미진진한 게임입니다! 오래갈거 같아요~ 강추! 술법의 개수를 늘려주세요.',
#  '게임은 좋은데 게임로그인 시간이 뭐이리 오래 걸립니까, 너무답답하네요.',
#  '심심할때 하기좋고 너무 어려운 단계가 있지만 그래도 별이5개!',
#  '무과금으로 즐기기에 부족함이 없는 갓갬 더 발전된 게임을 기대하며 최소한의 과금은 필요 하겠죠? ㅎㅎ',
#  '폰겜 잘안하는데 이건 재밌네요 오랜만에 현질도 해보고, 소과금이지만 쏠쏠하이 즐기고있습니다',
#  '광고로 시작했는데 생각보다 재밌네요 아직 시작단계라 과금 유도는 잘 모르겠으나 아직까진 재밌어용 ㅋㅋㅋ',
#  '재밌는데 컨텐츠가 너무 한정적이라 계속 같은 패턴이다',
#  '간편한 조작에 소소한 재미 할거없으신분들께 추천드립니다.',
#  '닌자대전을 키는데 계속 꺼지고 또 꺼지고 진짜로 언제 켜질까요?ㅠㅠ 망했네요...',
#  '너무재밌는데 영혼석 기본 갯수좀 많이 늘려줬으면 좋겠습니다',
#  '아직은 초반이라 그런가 너무 재미납니다 인술 너무 멋져요!!',
#  '제가 오랜만에 들어와서 복귀유저 출석체크를 받고있었는데 마지막보상이 받았다고 뜨는데 우편함에는 아무것도 없네요... 이 경우엔 어떻게 해야 하나요?',
#  '재미집니다. 그래픽, 타격감, 스토리 모두 맘에 듬!',
#  '한국 웹툰 같은 겜이라 친숙해서 좋구요 운빨과 나름 어떻게 키워야 할지 고민하게 만드는 재밌는 겜입니다',
#  '저도 제가좋아하는 게임입니다 근데언제서 부턴가 게임을 시작하면 튕기는군요 빨리 고쳐주셨으면합니다',
#  '저는 2일차인데 벌써5성이 2개나 뜨고 심심할때 하면 재미있는 게임같어요!',
#  '오늘 처음하였는데 정말재밌어요. 아기자기한 케릭터와 닌자가 요괴를 토벌한다는 스토리를 가졌지만 정말하나도 무섭지않아요. 저의 베스트5안에 들어가는 인생게임!!! 제작자님 화이팅!!!',
#  '간만에 찾은 갓겜 광고없고 현질유도 없고 무과금으로도 충분히 즐길수있음',
#  '타격감도 좋고 기술도 여러가지 많아서 정말 재미있네요.',
#  '한판하고 지우려했는데 계속하니까 진짜 재미지네요 잘 만드셨어요',
#  '스테이지에 입장하기전에 적군의 속성을 알려주면 좋을것 같습니다.',
#  '큰 과금유도도 없구 일단 상위기술 체험모드가 제일 좋은거같아요 ㅋㅋㅋㅋ',
#  '좋은데 템강화만있고 판매는없네요.. 기본중에 기본..',
#  '애니매이션과 그림체가 너무 마음에 들고 스토리도 재밌습니다. ^^',
#  '게임은 신나고 재미있는데 캐릭터를 얻기가 어려워서 아쉬워요',
#  '일단 게임은 다 좋습니다 근데 제가 가끔씩 지웠다깔고 하는 유저거든요? 근데 계정이 날아갔어요 제가 별점1인 이유는 이거여서 그럽니다 3번정도 지웠다 깔고 그 지도에있는 최종지역 끄트머리까지 갔거든요? 열심히 한건데 너무나도 아쉽네요 그래서 절대 지웠다 깔지마세요 저처럼 계정 날아가시면 안돼요 복.....구가 될지 모르겠네요 그럼 게임 만드시는 분들 고생하시지만 이런것좀 고쳐주세요',
#  '성🏰스테이지7단게를 진입했는데 계속이겨도 도전 실패라고 떠요 이 버그좀 빨리 수정 부탁드려요 답변도 부탁드려요',
#  '업데이트 필요하다 그래서 플레이스토어가면 업데이트 이미되있어서 플레이버튼 누르면 다시 업데이트 필요하다 그러고 다시 스토어 다시 플레이 무한반복',
#  '직관적이고 매우 재밌습니다. 그래픽도 깔끔하구요',
#  '게임은 재밌으나 페이스북 과대광고때문에 기분이좋디않네요',
#  '정말정말 재밌어서 매일같이 하는데 이번패치에서 광고보기가 나왔더라구요. 광고 보고 추가아이템 받을려고하는데 광고때매 자꾸 닌자대전어플이 멈춰버리는데 빨리 조치좀 해주세요~',
#  '버그 수정 업뎃만 해주시면 5점도 드릴 수 있을 것 같습니다.',
#  '동생이 추천해준 게임인데 재미없을주 알았는데 막상 해보니까 재밌더라구요 앞으로 재밌게 플레이 하게습니다 감사합니다 운영자님',
#  '할수록 재미있어요. 좋아요 😀',
#  '재미는있는데 오류뜨면서 한번씩 멈춤 pvp매칭이 시스템이있긴한가 싶을정도로 어이없는 매칭',
#  '찐~짜 재밌어요 그리고 중독성이 있어여 그리고 광고도 안나오고 저의 최애 게임 이에요 별5개 드립니다',
#  '게임중에 갑자기 에러라고 뜨면서 튕기고 그 뒤로는 아예 못들어가네요 어떻게 된건가요...? 그냥 깔아서 순수하게 즐기고 있었습니다',
#  '스사노오 개깐지 ㅋㅋ 진짜 다 좋은데 한 가지 단점이 있다면 스킬 쓸수 있는 칸을 조금만 늘려주세요 ㅜㅜ',
#  '재미있기는 한데...스토리추가 언제하나요??? 스토리 추가 빨리 해주세요. 현기증 난단 말이에요.',
#  '스킬 타이밍 맞추면서 플에레이 하는게 난이도도 적당하고 재미있네요',
#  '게임내 캐릭터 디자인이 너무맘에들고 아이디어도 좋은것같아요 ^^',
#  '왠만하면 리뷰안쓰는데 이겜 진짜 재밌네ㅋㅋㅋㄱㄲ 아쉬운점은 전투는 1분컷인데 영혼석은 10분에 하나ㅜ',
#  '게임도 재밌고 현질도 별로안해도 잘할수 있어서 좋아요!',
#  '잼나네요 모바일게임 이렇게 오래잡고 있눈것도 첨 123시간 ㅋ 근데 아이템드랍률 너무 극악',
#  '재미는있으나 기본적으로 데이터먹는게임인데 그래픽이 후짐',
#  '재밌는데 피로도가 조금만 더 빨리 찾으면 좋겟네요',
#  '쉽고 재미져요 캐릭마다 스킬이 달라서 더 키우고싶고요',
#  '아니들어가려고하는데요든어가지지안고그냥나가저요다시해도똑같고다시시작해도똑같아요지웠다해도똑같고요그건만고쳐주시면☆☆☆☆☆개드리겠습니다',
#  '재밌어요. 노가다만 하면 충분히 과금 안 하고도 잘 할 수 있습니다.',
#  '정말 재미있는데스킬장찬하는슬록만 1칸늘려주었으면좋겠습니다그러게임재미있게하겠습니다.^^',
#  '아직 머가먼지 도통 알수가 없네요 걍해볼께요',
#  '게임을 아주 잘 만들었네요ㅎㅎ 근데 재밌긴 한대 난이도를 성9만 쫌 줄여주세요ㅎㅎ',
#  '아니ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 어이가 없어서 배-4까지는 진짜 쉬웠는데 갑자기 배-5부터 왜이리 어려워지는건데요? 그럼 앞으로는 뭐 어떻게 깨라는건지 아 접으라는건가',
#  '계정이 증발했는데 무과금 유저는 결제 기록 없으면 복구 못하네요..',
#  '두루마리 확률좀 보여줬음합니다 소환수도 많아지면좋을듯',
#  '할때마다 신기하고,재미있는 스토리가 있어서좋아요.',
#  '재밌네요 근데 영웅을 얻을 수 있는 수단이 좀 더 생겼으면 좋겠어요',
#  '우와 이건 갓겜입니다 와 겁나게 재미있습니다 앞으로도 새로운 플레이어들이 생기길바랍니다',
#  '처음하는데 처음부터 점검이여서 끝나고 업데이트 하려는데 업데이트가 안돼요',
#  '생각보다 꽤나 재미있어서 5개월째 하는중인데 아이템 확율만 좀 올려주면 더 많이할듯 합니다',
#  '몰입감이 최고 근데 무과금은 오래하기 힘들듯하네여 초반에는 괜츈',
#  '앱 개발자님 진심으로감사드립니다 진짜재밌고 게임에 정말 공들이신거같아요 진짜재밌어요 이런게임만들어주셔서 감사합니다 진짜 이게임이 왜 다운로드수 10만회밖에안되는지 의문이들정도네요 진짜재밌어요 감사합니다',
#  '게임도 재밌고 인터페이스도 깔끔하고 좋네요',
#  '아직 게임이 안떠오른거에요 이리 재밌는 게임이 않뜰일이 있겠어요? 어제 시작했는데 정말 재밌네요 게임 천천히 기다리면 인기있어질겁니다 개발진분들 모두 화이팅 하세용!',
#  '일단 재미있어요 그런데 전체적인 벨런스가 아쉽네요 배를 탈출못함',
#  '처음할때무지성으로달리다가실패해서재미없었는데 다시해보니깐 재밋네요',
#  '현질없이 할수잇고 노가다가 귀찮지만 그래도 확실히 키우는맛은 다른게임보다 많음',
#  '재미있는데 돈을 었기 너무 힘듬니다ㅠㅠ 기술도 넘 안좋아요.',
#  '게임도 재밌고 만드신분들 열정도 대단하시고 좋은게임이네요',
#  '완전완전갓겜! 1시간했는데 벌서성?! 완전 갓겜! 그리고 제작자님도 많이의견이 보내주셔서 너무감사하고 완전강추!',
#  '오늘깔아보는데 배경음악만나오고 로딩은 안돼어서... 로딩하는것좀 고쳐주세요',
#  '재미 있어요~^^하지만 시간때문에 못껠때가 만아요.시간을 없세주면 좋겠네요~',
#  '간단하면서도 크게 신경쓰지 않아도 무난히 할 수있어서 좋습니다.',
#  '오... 잘만들었네요 헌데 꼭 닌자가 아니라도 다양한 케릭도 있음좋겠어요 이순신이나 광개토처럼',
#  '재밌어요. 현질하면 시간단축이 많이 되내요',
#  '이야 이거 너무 재미있다 그리고 주인공 목소리 너무 좋네 인술 너무 재미있고',
#  '와.. 완전 최고에요!!!! 그런데 이게임은 자동저장인가요? 그리고 게임종료버튼이 없는데 어떻게 하나요?',
#  '아..다 좋은데 아이템 확율 좀 올려주세요.. 잘 좀 부탁합니다 ^ -^ 아 또 성9 난이도가 급상승이어서 초보들이 힘들어함',
#  '재미잇게 하고잇어요ㅎ 근데 육성법좀요 ㅜㅜ 깨는게 점점 어려워져여 ㅜㅜ',
#  '다 좋은데 결투장 스펙차이 벨런스 패치가 필요하다 생각합니다 말도 안되는 사람들이랑 매칭이너무심하게되요',
#  '게임 재미있는건 둘째치고 운영자 소통이 너무 빨라서 당황 이메일 피드백이 워...',
#  '캐릭터도 좋고 장비도 잘주고 너무혜자여서 좋아요!',
#  '세심하게 잘만들었네요ㅎ 업데이트만 잘된다면 대박날듯',
#  '즐거움과 행복한 게임에 박수를 보냅니다. 하루의 피로, 스트레스 닌자의 수리검으로 해결완료. ^^',
#  '두번째 리뷰네요 ㅋㅋ 광고만 잘봐도 현질 안하고 할수 있겠네요 ㅋ',
#  '간단하고 시간때우기 좋구요 재미도 있네요~',
#  '너무 어려워요 난이도 고쳐주세요 근데 성이 어렵고 다른데는 완전 쉬워요',
#  '어느정도 난이도 높은 구간에서 더이상 나아가기 힘듬',
#  '게임은 너무나 재미있게 하고 있어요 업데이트 자주 해주세용 ㅎㅎ',
#  '난이도적당 재밌어용 스킬도많아서좋아요근데 5성확률좀높에주세요(빨리요) 안녕 ㅂㅇㅂㅇ',
#  '다 좋은데 불타는괴동 정예 난이도 잡을때 한방에 가버림. 이유도 없고 체력도 풀피인데 한방에 가버리네 이 버그인지 모르겠을것을 좀 해결해줍쇼.아님 설명해주시던가.',
#  '불,물,돌,풀다삿는데번개도나왔으면좋겠어요. 스킬 놓는공간도하나만늘려주세요.',
#  '재밌습니다! 자동 플레이가 있으면 더 재밌을거 같아요 ㅎㅎ',
#  '플레이 하고 싶은데 플레이가 안 되네요, 내폰 게임이 많아서 그런가 플레이 하면 수정😉',
#  '가볍게 즐기기 좋습니다 그림도 아기자기하고 예뻐요',
#  '중간중간 짧은 만화도 재밌고 스킬 연계 만들어내는것도 재밌음 그리고 주인공 목소리 좋아',
#  '재밌어요. 어렵다고 찡찡대는 리뷰 많이 보여서 현질유도 심한가 했는데. 걍 겜할줄 모르는 애들이네요. 현질유도 없고, 5성유닛 못뽑을수 없을만큼 혜자게임이에요.',
#  '인술이나 체술,환술에 목소리가 들어간게 너무 좋네요 ㅎㅎ',
#  '계속 팅깁니다 와피아이도 데이터도 계속팅겨요 폰은 LG U+인데 왜 팅기는지 모르겠네요',
#  '수 시간 투자하며 키운 걸 구글 연동 하나 눌렀더니 초기화됨 계정 날라갔는데 친절하게 답변해 주시면서 복원시켜 주셨습니다. 정말 좋아하던 게임이 날라가서 짜증났는데 복원되니 갓겜이 맞네요.',
#  '게임은 재미있는거 같은데 광고제거 가격이 부담스럽네요',
#  '개인적으로 강화하는게 오르는 수치가 넘 적다고 생각해요. 무기나 닌자 레벨업이나',
#  '진짜재밌어요 아이템도 많이주고 저가 좋아하는 게임 방식이어서 별다섯개를 줍니다',
#  '생각보다 아기자기 재밌네요 일주일째 천천히 즐기는중ㅎㅎ',
#  '너무 재미있는 갓겜!',
#  '간단한 게임인데도 엄청 재밌어요. 전설은 좀 많이 안 주지만요',
#  '정말 재밌지만 아이폰으로 바꾼후 계정 연동이 어렵네요... 답변 바랍니다..',
#  '중간부터좀많이어려워요그리고5성도잘안나오구요5성확률높여주세요~^^(단계도쫌만쉽게부탁해요)감사합니다♥♥',
#  '킬링타임용으로 좋네요 저도 모르게 3~4시간씩 플레이하게되요',
#  '제가 3대의 기기를 사용해 접속을 하려하는데 모두 접속이 안되네요...복귀하려는데',
#  '버그가 있네요 그 보스전에서 광고봐도 보상이 없어요 그리고 웅덩이 보스 6에서 클리어했더니 렉이 걸리더니 보상도 없고 무한 렉이 걸려요',
#  '게임 요즘 게임들과는 다른 형식의 게임이지만 정말 재미습니다 꼭 한번쯤 해보세요',
#  '할만하긴한데... 난이도가 특정스테이지 기준으로 개빡씨게 변하면서 지루해짐.',
#  '진짜 퀄리티가 좋구요 그러고 재미 있어요 그런데 거기서 애니 까지 진짜 재미있음니다',
#  '다양한 게임스킬들과 캐릭터로 질리지않게 진행할 수 있어서 재밌다',
#  '닌자라는 주제에 걸맞게 인술 체술 환슬 등의 기술과 손동작이 있다는 점에서 놀랐고 잠깐등장하는 스토리가 재미있었다',
#  '재미있게하고있었는데 업뎃후 아에안들어가지네용 갤탭2 7.0이요 ㅠ',
#  '정말 재밌게 했는데 갑자기 에러 라고뜨면서 앱 실행자체가 안되네요',
#  '재밌게 잘 하고있습니다 컨텐츠 꾸준하게 늘려주세요',
#  '계속 로딩중이다가 19에서 튕기네요 재밌어 보여서 할려고 했는데 아쉽네요',
#  '아직은 무과금으로 즐기만해요 챕터5까지하는중 근데 역시 투기장은 고인물들이',
#  '하이요 반가워요 ^~^',
#  '잼나게 놀고 있어요 ㅋ',
#  '너무 어렵고 공략을 봐도 레벨이 높아야지 깰수있음',
#  '재미는 있는데 안드로이드랑 IOS랑 같이 연동해서 할 수 있는 계정 사이트 만들었으면 좋겠네요',
#  '게임을 하려는데 로딩이 이상라게되서 ㅍ,ㄹ레이가 불가능하다',
#  '게임이 로딩에서 들어가지지 않아요 패치 부탁드립니다',
#  '정말 재밌게 즐기고 있습니다. 다만, 밸런스조정을 해야할것같습니다 좀 특히 성 7이 살짝 밸런스가....어렵습니다 참고해주세요~~ ^^',
#  '재미있어요 ㅎㅎ디펜스게임 잘안하는데 이거는 귀엽고 아기자기한데 디테일해요',
#  '재밌네요 다양한 몹 패턴이 있었으면 더 좋앗을듯',
#  '연타기능이 있다는 광고를 봤는데 그건 어떻게 하는건가요? 빠른답변부탁드립니다',
#  '액션 좋고 스킬모션도 좋습니다 과금없이 즐길수 있어서 재밌습다',
#  '갑자기 잘되다가 계속 에러 떠서 재설치했더니 계정이 초기화되어있는데 어떻게 해야하나요^^',
#  '완전 개꿀잼 한번하면 못 빠져나오는 늪에 걸린든 빠져듬(^-^)',
#  '성단계가 너무어렵지만 저는 정말 재미있게 할 수 있어서 너무 좋았어요 갓겜입니다.',
#  '무료로도 충분히 즐길수 있는것 같으나 시간이 꽤나 걸리겠네',
#  '손을 눈보다 빠르게 움직여야 하지만 재미있다.',
#  '복기유저입니다게이은 재미있는데 성우 음성이안나와서요 이부분고처주셨스면합니다',
#  '다 좋은데 목둔 쓸때 이동만이 아니라 공격도 못하게 하면 좋을 것 같에요.',
#  '광고가 준비되지않았늡니다 문구가 계속떠서 못보고있어요! 해결방안 부탁드려요',
#  '진짜 재밌어요. 제가 나루토를 엄청 좋아하는 골수팬이라 이런게임 은근 안좋아 했는데 이건 진짜 게임성만 놓고 봐도 진짜 재밌네요. 디펜스 좋아하시는 분은 꼭 해보세요!',
#  '모든면에서 뛰어나지만 현질유도는 피하기가 힘드네요',
#  '재미있게 하다가 게임하려니까 자꾸 안들어가지고 검은화면 밖에 안떠요',
#  '아니 들어갔는데 갑자기 네크워크 문제라면서 못들어가고 네크워크 확인하고 들어가도 안되요ㅡㅡ 좀고쳐주세요',
#  '조작도 간편하고 캐릭터도 귀엽네요. 재미있습니다',
#  '애니메이션도 재미있고 어떤 목적으로 게임을 플레이 하다보니 저 재미있는 덧 같네요.',
#  '가끔 튕기는 것 같은 자잘한 버그가 있지만 재미있네요!',
#  '솔직히진짜 노가다임 현질이답이긴한대 너무하다는생각이듬',
#  '사정이 있어서 삭제 했다가 다시 깔았는데 원래 하던 그대로 다시 못하나요 다시 그만큼 하기 너무 힘들어요',
#  '너무 많이팅겨요ㅡㅡ 스테이지한번클리어하고 또 팅기고 또팅기고 ㅡ',
#  '조작법은 간단하고 머리는 많이쓰고 재밌네요 !',
#  '겜은 할만한데 신규 유저 보상 이런거 없고 퍼주는거 없는 겜. 출석체크만 있음. 일단 하고있긴한데 지울까말까 고민중',
#  '아이템을 잘 나오게 해주세요 그리고 우편도 좀... 많이 넣어 주셨으면..',
#  '현질이 안돼요 계속 터치하는데 구매창은 안열리고 게임은 못깨고 있고 답답해요',
#  '재밌네요ㅎㅎ아직초보이지만 쉽게할수있네요',
#  '매우 재미있음. 단순하지 않고 조합 생각 많이해야함.',
#  '하기는 재미있게 하고 있어요 그런데 대요괴 토벌이 어려운데 난이도 좀 낮춰 주세요',
#  '업데이트 하고 엄청 튕김 광고보고 추가 보상 받는데 12퍼 되면 튕겨요 겜은 재밌음',
#  '게임이 시작이 안되는데요?? 재설치를 계속해봐도 안됩니다 게임은 재미있을거같아서 5점드리구요 해결좀 해주세요',
#  '많이하다보니까 조금 질리네요.....그레도 1달에 1번은 들어가니깐 갓갬 인정!',
#  '광고로접하게 됐는데 재밌어요ㅎㅎ아직까진요',
#  '계정 연동을 하는 중에 다른계정으로 연동 이런게 떠서 확인했더니 아이템이 초기화 되버렸네요 복구 안돼나요?',
#  '게임 자체는 잘 만들었는데 현질없이는 진행하기에 밸런스가 안 맞는다',
#  '재밋게 플래이 하고 있는 유저인데요..둔을 더 추가해주세요ㅜ예를 들어 폭둔,정둔,뇌둔,풍둔 같은거요 더 추가해주세요',
#  '옛날 플래시게임 하는 느낌이 나네요ㅋㅋ 음성지원도 어색하지 않고 좋아요~',
#  '진짜로진짜진짜 이거하나 아니 확률또같은거맞나욤 개발자님 저만확률줄이는거죠 핓빗12개금화 로질러서 했는데하나도안나오고 또다음날8개질러서갔는데 하나도안나오고🐴이됌요?사촌형은 저보다1주일더늦게했는데 나보다전투력이좋타구요!사촌형은 2판만에좋은거나오드만',
#  '은근 중독성 있고 단순하면서도 지루하지 않은 게임입니다',
#  '업데이트하고 뭐 할때마다 버퍼링 1시간씩 가는데 서버좀 늘리시거나 관리좀하시죠 선생님들',
#  '광고 많이 봐줘야 하긴 하지만 재미는 있다',
#  '이 게임은 중독성 갓겜입니다 한번 들어가면 1~2시간 순삭임',
#  '스킬쓸때 화둔! 하면서 소리가 났었는데 왜 지금은 그 소리가안나죠?',
#  '재밌네요 개발자가센스도있으시고요 꼭 예전피시게임 환세취호전을 보는것같습니다',
#  '버스문의)스킬 체험하기 들어가면 몹이안나와요 버그인것 같아요 수정부탁드립니다..',
#  '못깨는 단계가 나오면 깰려면 시간이 너무 많이 들어요',
#  '게임이 아예 안들어가져요 얼른 고쳐주새요 겜은 너무 재밌어요',
#  '기대 이상으로 재밋습니다 캐릭터들도 귀엽고 좋습니다',
#  '갤럭시 s10인데 게임이 안돌아갑니다 계속 검은화면떠요',
#  '생각보다 재밌어요 계속하게되네요 뭐 욕심없으면 과금 없이 계속할수있어요',
#  '게임은 재밌지만 아이템 좋은것도 안뜨고 성밸런스가 너무 어려움',
#  '재밌어요 다양한 기술들도 창의성이 돋보입니다',
#  '재미있습니다만 재화 수급이 용이했으면 좋겠습니다',
#  '게임이 너무 자주튕기네요.. 좀 고쳐주셨으면합니다..',
#  '예전에 재밌게 플레이 했어서 다시 깔려고 보니까 계정 연동이 안되는 것 같아요.. 계정복구 가능한가요?',
#  '게임 하고 후기 쓴 건 처음입니다. 하루종일 폰 못 놓았어요. 올해 최고의 게임입니다.',
#  '무과금으로 하는중인데 아직까지 막힘없이 재미있게 하고 있습니다',
#  '재미있지만 스테이지에서 지면 장비교체 밖에 해야 할수있어요',
#  '아직까진 열심히 하는중인데..그냥 너무 애가타게만듬..',
#  '게임은 재밌습니다 그런데 그 술법 숙련도 100이고 금화 45000도있는데 왜 숙련도가 부족하다고뜨죠?',
#  '아니 계속튕겨요 그래서 게임을 할 수가 없어요 그래도 재밌어보여서 2점줄게여....ㅠㅠ',
#  '재미있습니다 1가지가 불편합니다 기술를 살려고 돈를 모을려고 했는데 몬스터를 잡기가 여려워요 살짝 몬스터를 약하게 해주시면 감사하겠습니다',
#  '이제 시작했는데 광고 없고 충분히 무과급으로 할만하네요',
#  '대사목소리도 좋고 게임판도 길지않고 재미있네요',
#  '평범하지만 특색이있어서 할만함 하지만 템 드랍율이 헬',
#  '가볍게 할수있고 현질 유도가 심하지 않아 재미있습니다',
#  '꼭깔아보세요 전투할때아이템이안나와짜증날데도있지만 토벌권이있어아이템을었을수있어요 추천게임입니다.',
#  '재미있습니다 강해지려면 광고를 많이 봐야하겠네요',
#  '재미는 있다만 아템.. 안습이다 산군깃발이나 귀린담장 지발쫌!',
#  '이게 진짜 갓겜이에요 근데 현질을 하지 않고하는것이 너무 어려워서 아쉬워요',
#  '개꿀잼이긴한대 오프라인이 않돼서 좀 아쉬움 오프라인 없으면 개꿀잼일거같음!!!',
#  '재미있어용!^^ 강화하기가 어렵긴히지만..ㅎ',
#  '서버비(과금요소)가 과하게 측정되지 않았나 합니다. 소과금으로 하기엔 다소 부담되는 금액이네요',
#  '과금안해도 충분하게 즐길수있음 중독성 있고 재밌음',
#  '아직까지는 재미씀 :D 작화가 넘나 맘에듬',
#  '광고 텀을 조금만 줄여주면 좋겟네요',
#  '광고봐도 보상 안 들어옵니다 두번 봤는데 다 안 들어오네요',
#  '광고보고 은패얻기했는데 광고30초보고 은패가 안들어오네요',
#  '맵좀 더 만들어주셨으면 좋겠어요 전체적으로 게임만족도는 좋네요',
#  '제발그보상안나오는버그좀고쳐주세요계속안나와서짜증납니다별을주기싫습니다진짜',
#  '잡는맛도있고뽑는맛도있어서재밌는데보스스테이지가좀 어려움',
#  '은근히 잘만듬 1챕터 마지막 성구긴이 어렵긴한데 재밌으면 됬지',
#  '재밌습니다. 생각 보다 재밌네요. 리니지 하다가 심심해서 했는데 빠졌습니다.',
#  '게임은 재미있는데 광고보기가 안되는경우좀 고쳐주세요 ㅜㅜ',
#  '아니 투급 5만 밖에 안됬는데 순수대련에서 막 투급 4백만짜리 만나고 재탐색 하는데 천만짜리만나고 어이가 없어요 제발 저와 비슷한 투급의 사람과 붙이시면 좋겠네요',
#  '불물땅나무도괜찮지만 여러가지도 더 나오면 재미겠어요.',
#  '업뎃 어케하는거야? 하란거야 말란거야? 업뎃하라길래 누르면 구글스토어에 업뎃 안나옴 플레이만나와서 겜으로가면 다시업뎃으로 무한 반복임',
#  '시작한지 별로 안돼서 잘 모르지만 더 하다가 피트벡 남길게여',
#  '로딩이 다 된후 게임이 실행되지 않고 튕기네요^^ 해보지도 못했어요!',
#  '아들하고 즐겁게 하는유일한게임인데 어제 갑자기 초기화 되었어요 이멜 보냈는데 아직 복구가 안되었어요 복구좀 부탁합니다',
#  '번개 기술이 없어 좀 아쉽지만, 잼있네요^^',
#  '아래처럼 렉이있거나 튕기거나 스킬이 안먹히는그런버그는 하나도 없는데 수둔 목둔 이렇게 외치는거 어떻게해요 듣고싶은데',
#  '재밌는데 나루토를 배낀 것 같네요..... 게임은 재밌게 하고 갑니다',
#  '평이 좋아서 기대하고 했는데 검은 화면 밖에 안보임',
#  '아니 게임을하려는데 안들어기지면서 로딩이 막 왔다갔다거리네요',
#  '그냥 평범 조금더 해보면 재미를 느낄듯',
#  '퀄리티가 너무좋고, 액션이나 스킬들쓰는맛이있너 재밌어요 이럼게임 만들어주셔서 감사합니다',
#  '게임은 너무너무 재있는대 난이도가 너무 힘들어요',
#  '오랜만에 들어가려 했는데 리소스 확인에서 멈추고 들어가지지 않아요 빨리 들어가고 싶네요',
#  '재밌긴한데 광고 보고 자주 팅겨요 ㅠ 그것만 아님 더 좋을듯요',
#  '기술 봐꾸기가 재미고 기술의 이펙트가 좋았요.',
#  '케릭터도 귀엽고 스토리도 나름있고 다른방식의 디펜스 잼있다 닌자게임중 최고',
#  '로딩하면에서 넘어가야 되는대 안넘어가고 계속 ㅇ애러가 뜹니다',
#  '선생님 게임이 너무 자주 팅기는데 ㅃㄹ 고쳐주십쇼 ㅠㅠㅠ 겜은 재밌는데 드가지를 못하네요',
#  '재밋으면서도 먼가 복잡네요ㅎㅎ할만합니다',
#  '닌자물을 좋아해서 그런진 모르겠는데 오랜만에 폰에 겜깔고 계속하네요 ㅋㅋㅋㅋㅋ',
#  '시간도 잘가고 과금 유도도 없고 느므 재밌어요',
#  '미션이 짧긴하지만 나름 키우는 재미가 있어요 무과금으로 할만해요',
#  '아니 게임이 계속 튕귀고 들어가져도 튕김 좀 해결좀 해주세요ㅠㅠ',
#  '재미있습니다. 과금유도도 딱히없어요 과금하면 도 쉬운정도??',
#  '이거재밌긴한데지웠다가까니깐게임이안돼요. 로딩하다가나가져요.그거좀고쳐주세요.',
#  '전략적 게임 잼있어요 ..광고가 보는건 힘드네요',
#  '재미는 있지만 광고를 너무 많이 봐야함',
#  ...]

# %%
labeled_data.to_csv('./train_review_data.csv', index=False)

# %%
pip install WordCloud
# Out:
# Collecting WordCloud
#   Downloading wordcloud-1.8.2.2-cp38-cp38-win_amd64.whl (152 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from WordCloud) (1.23.0)
# Requirement already satisfied: pillow in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from WordCloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from WordCloud) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from matplotlib->WordCloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from matplotlib->WordCloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from matplotlib->WordCloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: six in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from cycler>=0.10->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# Out:
# C:\Users\maius\anaconda3\envs\datascience\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
wordcloud = WordCloud(font_path='malgun').generate(' '.join(train_review))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
print('긍정 리뷰 갯수: {}'.format(labeled_data['label'].value_counts()[0]))
print('부정 리뷰 갯수: {}'.format(labeled_data['label'].value_counts()[1]))
# Out:
# 긍정 리뷰 갯수: 5654
# 부정 리뷰 갯수: 594

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp38-cp38-win_amd64.whl (344 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from konlpy) (1.23.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from konlpy) (4.6.3)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Tokenizer
# Out:
# Collecting TokenizerNote: you may need to restart the kernel to use updated packages.
#   Downloading tokenizer-3.4.2-py2.py3-none-any.whl (79 kB)
# Installing collected packages: Tokenizer
# Successfully installed Tokenizer-3.4.2

# %%
pip install --upgrade tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.10.0-cp38-cp38-win_amd64.whl (455.9 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.50.0-cp38-cp38-win_amd64.whl (3.7 MB)
# Requirement already satisfied: packaging in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (21.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp38-cp38-win_amd64.whl (896 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (1.23.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (2.10.0)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (1.12.1)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Collecting gast<=0.4.0,>=0.2.1
# Note: you may need to restart the kernel to use updated packages.
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (1.16.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: setuptools in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorflow) (58.0.4)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.13.0-py2.py3-none-any.whl (174 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.26.0)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\maius\anaconda3\envs\datascience\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-22.10.26 gast-0.4.0 google-auth-2.13.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.1

# %%
import re
import json
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

labeled_data = pd.read_csv('./train_review_data.csv')

labeled_data['content'][:5]
# Out:
# 0    이 게임이 갓게임인 이유 1.5성은 극악의 확률이다. 이런것 없이 5성닌자들이 많이...
# 1    게임 재밌게 잘하고있습니다. 근데 요번에 업데이트를 한 후 버그가 약간 있는것같습니...
# 2    게임방식이 직관적인 반면 스킬 조합 부분에서는 흥미가 일만한 퍼즐 요소가 있어서 굉...
# 3    정말 제 인생겜입니다, 컨트롤이 중요시되며 좋은 아이템도 많이 드랍해주어서 무과금도...
# 4    게임 다 좋고 재밌습니다. 자기 노력만 있다면 투자한 시간만큼 스펙업도 됌 아직 수...
# Name: content, dtype: object

# %%
labeled_data[labeled_data['rating']==2]
# Out:
#        num           date  rating    userName  \
# 7        8  2019년 12월 14일       2  Google 사용자
# 28      29   2019년 9월 27일       2  Google 사용자
# 48      49   2022년 8월 19일       2          익명
# 53      54   2022년 8월 30일       2         전대준
# 54      55   2022년 8월 31일       2         정태영
# ...    ...            ...     ...         ...
# 5715  5716  2020년 10월 22일       2         황성진
# 5974  5975    2020년 6월 3일       2         김수길
# 6171  6172   2020년 5월 13일       2          골드
# 6358  6359    2020년 4월 3일       2  Google 사용자
# 6487  6488   2020년 4월 17일       2  Google 사용자
#
#                                                 content  label
# 7     게임 자체는 재밌음 그런데 스킬 밸런스 차이가 너무 심해요. 어떤 스킬은 고정으로 ...    1.0
# 28    스테이지가 늘어날수록 난이도와 들어가는 돈은 많아지지만 획득머니가 너무 작습니다. ...    1.0
# 48    몇번이나 에러로 나가지는지 모르겠네요. 아무 전조도 없이 에러가뜨고 껏다켰다 반복하...    1.0
# 53    이번 업데이트 되면서 게임을 들어가면 검은 화면이 뜨면서 바로 튕기면서 나가지는데 ...    1.0
# 54            업데이트이후, 키자마자 꺼집니다 재설치를 해도, 폰재부팅을해도 마찬가집니다    1.0
# ...                                                 ...    ...
# 5715                                           화이팅 하십시요    1.0
# 5974                                               재밋네요    1.0
# 6171                                                  굿    1.0
# 6358                                        자동.........    1.0
# 6487                                                 굿겜    1.0
#
# [127 rows x 6 columns]

# %%
#전처리 함수 만들기
def preprocessing(review, okt, remove_stopwords = False, stop_words =[]):
  #함수인자설명
  # review: 전처리할 텍스트
  # okt: okt객체를 반복적으로 생성하지 않고 미리 생성 후 인자로 받음
  # remove_stopword: 불용어를 제거할지 여부 선택. 기본값 False
  # stop_words: 불용어 사전은 사용자가 직접 입력, 기본값 빈 리스트

  # 1. 한글 및 공백 제외한 문자 모두 제거
  review_text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]','',review)
  
  #2. okt 객체를 활용하여 형태소 단어로 나눔
  word_review = okt.morphs(review_text,stem=True)

  if remove_stopwords:
    #3. 불용어 제거(선택)
    word_review = [token for token in word_review if not token in stop_words]
  return word_review

# %%
# 전체 텍스트 전처리
stop_words = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한']
okt = Okt()
clean_train_review = []

for review in labeled_data['content']:
  # 리뷰가 문자열인 경우만 전처리 진행
  if type(review) == str:
    clean_train_review.append(preprocessing(review,okt,remove_stopwords=True,stop_words= stop_words))
  else:
    clean_train_review.append([]) #str이 아닌 행은 빈칸으로 놔두기

clean_train_review[:4]
# Out:
# [['게임',
#   '갓',
#   '게임',
#   '인',
#   '이유',
#   '성은',
#   '극악',
#   '확률',
#   '이다',
#   '이렇다',
#   '없이',
#   '성',
#   '닌자',
#   '많이',
#   '나',
#   '와',
#   '키우다',
#   '잼',
#   '있다',
#   '내',
#   '맘',
#   '대로',
#   '술법',
#   '을',
#   '고르다',
#   '쓰다',
#   '재미',
#   '있다',
#   '게임',
#   '엔',
#   '연출',
#   '화려하다',
#   '술법',
#   '많다',
#   '그',
#   '레',
#   '서',
#   '눈',
#   '을',
#   '호강',
#   '시키다',
#   '몬스터',
#   '있다',
#   '없어지다',
#   '정말',
#   '좋다',
#   '스테이지',
#   '많다',
#   '아주',
#   '좋다',
#   '차근차근',
#   '스테이지',
#   '를',
#   '깨다',
#   '나름',
#   '대로',
#   '스토리',
#   '도',
#   '있다',
#   '재미',
#   '있다',
#   '막히다',
#   '부분',
#   '공략',
#   '법',
#   '을',
#   '보다',
#   '닌자',
#   '을',
#   '육성',
#   '하다',
#   '깨다',
#   '재미',
#   '있다',
#   '단점',
#   '대',
#   '요괴',
#   '토벌',
#   '에서',
#   '좋다',
#   '장비',
#   '나오다',
#   '확률',
#   '너무',
#   '극악',
#   '이다',
#   '멀다',
#   '성',
#   '닌자',
#   '뽑다',
#   '확률',
#   '을',
#   '몰다',
#   '빵',
#   '하고',
#   '을',
#   '극악',
#   '으로',
#   '낯',
#   '추다',
#   '같다',
#   '근데',
#   '예외',
#   '도',
#   '있다',
#   '잘나오다',
#   '사람',
#   '도',
#   '분명',
#   '있다',
#   '하지만',
#   '그레',
#   '도',
#   '확률',
#   '을',
#   '조금',
#   '더',
#   '올리다',
#   '좋다',
#   '그',
#   '레',
#   '도',
#   '겜',
#   '갓',
#   '겜',
#   '이다',
#   '아무튼',
#   '만들다',
#   '분들',
#   '고생',
#   '많다',
#   '수고',
#   '하다'],
#  ['게임',
#   '재밌다',
#   '잘',
#   '하다',
#   '근데',
#   '요',
#   '번',
#   '에',
#   '업데이트',
#   '를',
#   '하다',
#   '후',
#   '버그',
#   '약간',
#   '있다',
#   '같다',
#   '대',
#   '전',
#   '댁',
#   '시간',
#   '마다',
#   '변경',
#   '되다',
#   '되다',
#   '대',
#   '전',
#   '댁',
#   '아니다',
#   '일',
#   '반',
#   '댁',
#   '을',
#   '바꾸다',
#   '대적',
#   '댁',
#   '시간',
#   '시간',
#   '으로',
#   '리셋',
#   '되다',
#   '확인',
#   '부탁드리다',
#   '그리고',
#   '업데이트',
#   '이후',
#   '에',
#   '서버',
#   '에러',
#   '자주',
#   '나오다',
#   '시작',
#   '하다',
#   '또',
#   '장비',
#   '를',
#   '바꾸다',
#   '후',
#   '전투력',
#   '변화',
#   '되다',
#   '덱',
#   '에',
#   '현',
#   '제상태',
#   '저장',
#   '을',
#   '누르다',
#   '전투력',
#   '이전',
#   '과',
#   '그대로',
#   '나오다',
#   '업데이트',
#   '감사하다',
#   '고생',
#   '하다'],
#  ['게임방',
#   '식이',
#   '직관',
#   '적',
#   '인',
#   '반면',
#   '스킬',
#   '조합',
#   '부분',
#   '에서는',
#   '흥미',
#   '일만',
#   '퍼즐',
#   '요소',
#   '있다',
#   '굉장하다',
#   '재밌다',
#   '또한',
#   '하다',
#   '스킬',
#   '사용',
#   '시',
#   '다른',
#   '스킬',
#   '을',
#   '동시',
#   '에',
#   '시전',
#   '하다',
#   '있다',
#   '속',
#   '도감',
#   '있다',
#   '좋다',
#   '카툰',
#   '식',
#   '디자인',
#   '이나',
#   '깔끔하다',
#   '인터페이스',
#   '그래픽',
#   '적',
#   '인',
#   '부분',
#   '도',
#   '흠',
#   '잡다',
#   '없다',
#   '아직',
#   '플레이',
#   '를',
#   '길다',
#   '해보다',
#   '아니다',
#   '단점',
#   '이라',
#   '하다',
#   '부분',
#   '을',
#   '발견',
#   '못',
#   '하다',
#   '흥미',
#   '이다',
#   '게임',
#   '이다'],
#  ['정말',
#   '제',
#   '인생',
#   '겜',
#   '이다',
#   '컨트롤',
#   '중요시',
#   '되다',
#   '좋다',
#   '아이템',
#   '도',
#   '많이',
#   '드랍',
#   '해주다',
#   '무과',
#   '금도',
#   '과금',
#   '러',
#   '뺨',
#   '치다',
#   '수준',
#   '으로',
#   '플레이',
#   '하다',
#   '있다',
#   '또',
#   '각',
#   '스테이지',
#   '마다',
#   '전략',
#   '을',
#   '세우다',
#   '플레이',
#   '를',
#   '하다',
#   '스테이지',
#   '를',
#   '클리어',
#   '하다',
#   '있다',
#   '때문',
#   '에',
#   '전략',
#   '을',
#   '세우다',
#   '재미',
#   '있다',
#   '정말',
#   '꼭',
#   '한번',
#   '플레이',
#   '하다',
#   '기르다',
#   '추천',
#   '드리다']]

# %%
#테스트 리뷰도 동일하게 전처리
test_data = pd.read_csv('./train_review_data.csv')

clean_test_review = []
for review in test_data['content']:
  if type(review) == str:
    clean_test_review.append(preprocessing(review, okt, remove_stopwords=True, stop_words=stop_words))
  else:
    clean_test_review.append([])

# %%
# 인덱스 벡터 변환 후 일정 길이 넘어가거나 모자라는 리뷰 패딩처리
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_review)
train_sequences = tokenizer.texts_to_sequences(clean_train_review)
test_sequences = tokenizer.texts_to_sequences(clean_test_review)

word_vocab = tokenizer.word_index #단어사전형태
MAX_SEQUENCE_LENGTH = 8 #문장 최대 길이

#학습 데이터
train_inputs = pad_sequences(train_sequences,maxlen=MAX_SEQUENCE_LENGTH,padding='post')

#학습 데이터 라벨 벡터화
train_labels = np.array(labeled_data['label'])

#평가 데이터 
test_inputs = pad_sequences(test_sequences,maxlen=MAX_SEQUENCE_LENGTH,padding='post')
#평가 데이터 라벨 벡터화
test_labels = np.array(test_data['label'])

# %%
DEFAULT_PATH  = './' # 경로지정
DATA_PATH = './' #.npy파일 저장 경로지정
TRAIN_INPUT_DATA = 'nsmc_train_input.npy'
TRAIN_LABEL_DATA = 'nsmc_train_label.npy'
TEST_INPUT_DATA = 'nsmc_test_input.npy'
TEST_LABEL_DATA = 'nsmc_test_label.npy'
DATA_CONFIGS = 'data_configs.json'

data_configs={}
data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab) + 1

#전처리한 데이터들 파일로저장
import os

if not os.path.exists(DEFAULT_PATH + DATA_PATH):
  os.makedirs(DEFAULT_PATH+DATA_PATH)

#전처리 학습데이터 넘파이로 저장
np.save(open(DEFAULT_PATH+DATA_PATH+TRAIN_INPUT_DATA,'wb'),train_inputs)
np.save(open(DEFAULT_PATH+DATA_PATH+TRAIN_LABEL_DATA,'wb'),train_labels)
#전처리 테스트데이터 넘파이로 저장
np.save(open(DEFAULT_PATH+DATA_PATH+TEST_INPUT_DATA,'wb'),test_inputs)
np.save(open(DEFAULT_PATH+DATA_PATH+TEST_LABEL_DATA,'wb'),test_labels)

#데이터 사전 json으로 저장
json.dump(data_configs,open(DEFAULT_PATH + DATA_PATH + DATA_CONFIGS,'w'),ensure_ascii=False)

# %%
# 학습 데이터 불러오기
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json
from tqdm import tqdm

#전처리 데이터 불러오기
DATA_PATH = './'
DATA_OUT = './'
INPUT_TRAIN_DATA = 'nsmc_train_input.npy'
LABEL_TRAIN_DATA = 'nsmc_train_label.npy'
DATA_CONFIGS = 'data_configs.json'

train_input = np.load(open(DATA_PATH + INPUT_TRAIN_DATA,'rb'))
train_input = pad_sequences(train_input,maxlen=train_input.shape[1])
train_label = np.load(open(DATA_PATH + LABEL_TRAIN_DATA,'rb'), allow_pickle=True)
prepro_configs = json.load(open(DATA_PATH+DATA_CONFIGS,'r'))

# %%
model_name= 'cnn_classifier_kr'
BATCH_SIZE = 512
NUM_EPOCHS = 10
VALID_SPLIT = 0.1
MAX_LEN = train_input.shape[1]

kargs={'model_name': model_name, 'vocab_size':prepro_configs['vocab_size'],'embbeding_size':128, 'num_filters':100,'dropout_rate':0.5, 'hidden_dimension':250,'output_dimension':1}

# %%
class CNNClassifier(tf.keras.Model):

  def __init__(self, **kargs):
    super(CNNClassifier, self).__init__(name=kargs['model_name'])
    self.embedding = layers.Embedding(input_dim=kargs['vocab_size'], output_dim=kargs['embbeding_size'])
    self.conv_list = [layers.Conv1D(filters=kargs['num_filters'], kernel_size=kernel_size, padding='valid',activation = tf.keras.activations.relu,
                                    kernel_constraint = tf.keras.constraints.MaxNorm(max_value=3)) for kernel_size in [3,4,5]]
    self.pooling = layers.GlobalMaxPooling1D()
    self.dropout = layers.Dropout(kargs['dropout_rate'])
    self.fc1 = layers.Dense(units=kargs['hidden_dimension'],
                            activation = tf.keras.activations.relu,
                            kernel_constraint=tf.keras.constraints.MaxNorm(max_value=3.))
    self.fc2 = layers.Dense(units=kargs['output_dimension'],
                            activation=tf.keras.activations.sigmoid,
                            kernel_constraint= tf.keras.constraints.MaxNorm(max_value=3.))
    

  def call(self,x):
    x = self.embedding(x)
    x = self.dropout(x)
    x = tf.concat([self.pooling(conv(x)) for conv in self.conv_list], axis = 1)
    x = self.fc1(x)
    x = self.fc2(x)
    return x

# %%
from tensorflow.keras.models import save_model

model = CNNClassifier(**kargs)
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy(name='accuracy')])

#검증 정확도를 통한 EarlyStopping 기능 및 모델 저장 방식 지정
earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=2)
checkpoint_path = DATA_OUT + model_name +'\weights.h5'
checkpoint_dir = os.path.dirname(checkpoint_path)

if os.path.exists(checkpoint_dir):
  print("{} -- Folder already exists \n".format(checkpoint_dir))
else:
  os.makedirs(checkpoint_dir, exist_ok=True)
  print("{} -- Folder create complete \n".format(checkpoint_dir))

cp_callback = ModelCheckpoint(
    checkpoint_path, monitor = 'val_accuracy', verbose=1, save_best_only = True,
    save_weights_only=True
)

history = model.fit(train_input, train_label, batch_size=BATCH_SIZE, epochs = NUM_EPOCHS,
                    validation_split=VALID_SPLIT, callbacks=[earlystop_callback, cp_callback])
# 모델 저장하기
save_model(model,'./model/')
# Out:
# ./cnn_classifier_kr -- Folder already exists
#
# Epoch 1/10
# 11/12 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.7793
# Epoch 1: val_accuracy improved from -inf to 0.95909, saving model to ./cnn_classifier_kr\weights.h5
# 12/12 [==============================] - 3s 87ms/step - loss: nan - accuracy: 0.7835 - val_loss: nan - val_accuracy: 0.9591
# Epoch 2/10
# 11/12 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.8443
# Epoch 2: val_accuracy did not improve from 0.95909
# 12/12 [==============================] - 0s 37ms/step - loss: nan - accuracy: 0.8453 - val_loss: nan - val_accuracy: 0.9591
# Epoch 3/10
# 11/12 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.8459
# Epoch 3: val_accuracy did not improve from 0.95909
# 12/12 [==============================] - 0s 38ms/step - loss: nan - accuracy: 0.8453 - val_loss: nan - val_accuracy: 0.9591
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000164FF291CA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('signature_function', 'signature_key'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000164FF291CA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('signature_function', 'signature_key'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000164FF291CA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('signature_function', 'signature_key'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/assets
# INFO:tensorflow:Assets written to: ./model/assets

# %%
INPUT_TEST_DATA = 'nsmc_test_input.npy'
LABEL_TEST_DATA = 'nsmc_test_label.npy'
SAVE_FILE_NM = 'weights.h5'

test_input = np.load(open(DATA_PATH+INPUT_TEST_DATA,'rb'))
test_input = pad_sequences(test_input,maxlen=test_input.shape[1])
test_label_data = np.load(open(DATA_PATH + LABEL_TEST_DATA, 'rb'))

model.load_weights('./cnn_classifier_kr/weights.h5')
model.evaluate(test_input, test_label_data)
# Out:
# 207/207 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.8567
# [nan, 0.8566666841506958]

# %%
DATA_CONFIGS = 'data_configs.json'
prepro_configs = json.load(open('./'+DATA_CONFIGS,'r'))
prepro_configs['vocab'] = word_vocab

tokenizer.fit_on_texts(word_vocab)

MAX_LENGTH = 8 #문장최대길이

sentence = input('감성분석할 문장을 입력해 주세요.: ')
sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\\s ]','', sentence)
stopwords = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한'] # 불용어 추가할 것이 있으면 이곳에 추가
sentence = okt.morphs(sentence, stem=True) # 토큰화
sentence = [word for word in sentence if not word in stopwords] # 불용어 제거
vector  = tokenizer.texts_to_sequences(sentence)
pad_new = pad_sequences(vector, maxlen = MAX_LENGTH) # 패딩

model.load_weights('./cnn_classifier_kr/weights.h5') #모델 불러오기
predictions = model.predict(pad_new)
predictions = float(predictions.squeeze(-1)[1])

if(predictions > 0.5):
  print("{:.2f}% 확률로 부정 리뷰입니다.\n".format(predictions * 100))
else:
  print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format((1 - predictions) * 100))
# Out:
# 감성분석할 문장을 입력해 주세요.: 게임 재밌게 잘하고있습니다.
# 1/1 [==============================] - 0s 24ms/step
# nan% 확률로 긍정 리뷰입니다.

# %%
DATA_CONFIGS = 'data_configs.json'
prepro_configs = json.load(open('./'+DATA_CONFIGS,'r'))
prepro_configs['vocab'] = word_vocab

tokenizer.fit_on_texts(word_vocab)

MAX_LENGTH = 8 #문장최대길이

sentence = input('감성분석할 문장을 입력해 주세요.: ')
sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\\s ]','', sentence)
stopwords = ['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한'] # 불용어 추가할 것이 있으면 이곳에 추가
sentence = okt.morphs(sentence, stem=True) # 토큰화
sentence = [word for word in sentence if not word in stopwords] # 불용어 제거
vector  = tokenizer.texts_to_sequences(sentence)
pad_new = pad_sequences(vector, maxlen = MAX_LENGTH) # 패딩

model.load_weights('./cnn_classifier_kr/weights.h5') #모델 불러오기
predictions = model.predict(pad_new)
predictions = float(predictions.squeeze(-1)[1])

if(predictions > 0.5):
  print("{:.2f}% 확률로 부정 리뷰입니다.\n".format(predictions * 100))
else:
  print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format((1 - predictions) * 100))
# Out:
# 감성분석할 문장을 입력해 주세요.: 노잼
# 1/1 [==============================] - 0s 22ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19528/937064725.py in <module>
#      17 model.load_weights('./cnn_classifier_kr/weights.h5') #모델 불러오기
#      18 predictions = model.predict(pad_new)
# ---> 19 predictions = float(predictions.squeeze(-1)[1])
#      20
#      21 if(predictions > 0.5):
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
