# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import random
import pandas as pd
import numpy as np

# %%
driver = webdriver.Chrome()

# %%
url = "https://www.inven.co.kr/board/lostark/4811?my=chuchu"
driver.get(url)

# %%
borad_list = driver.find_element(By.XPATH, '//*[@id="new-board"]/form/div')
posts = driver.find_element(By.XPATH, '//*[@id="new-board"]/form/div/table/tbody/tr[1]/td[2]/div/div/a')

# country_list = []


# for row in rwdata:
#     country_name = row.find_element(By.TAG_NAME, 'th').text
#     country_list.append(country_name)
#     print(country_list)

# %%
print(posts.get_attribute('href'))
# Out:
# https://www.inven.co.kr/board/lostark/4811/5855532?my=chuchu

# %%
title = driver.find_elements(By.CLASS_NAME, 'subject-link')[1]
print(title.text)
# Out:
# [잡담] 뉴비 세구 60각 주차 완료.

# %%
titles = driver.find_elements(By.CLASS_NAME, 'lgtm')
title = driver.find_elements(By.CLASS_NAME, 'subject-link')

title_list = []

for i in titles :
    title_list.append(i.text)
    print(title_list)
# Out:
# ['5855417\n[잡담] 뉴비 세구 60각 주차 완료.\n[26]\n사진\n팩폭전과17범 13:04 3,766 45']
# ['5855417\n[잡담] 뉴비 세구 60각 주차 완료.\n[26]\n사진\n팩폭전과17범 13:04 3,766 45', '5855411\n[잡담] 스포)황혼의 목적\n[38]\n사진\nGrunty 13:03 4,221 71']
# ['5855417\n[잡담] 뉴비 세구 60각 주차 완료.\n[26]\n사진\n팩폭전과17범 13:04 3,766 45', '5855411\n[잡담] 스포)황혼의 목적\n[38]\n사진\nGrunty 13:03 4,221 71', '5855374\n[잡담] 왕가슴 아르고스\n[28]\n사진\n파타1 12:55 3,361 36']
# ['5855417\n[잡담] 뉴비 세구 60각 주차 완료.\n[26]\n사진\n팩폭전과17범 13:04 3,766 45', '5855411\n[잡담] 스포)황혼의 목적\n[38]\n사진\nGrunty 13:03 4,221 71', '5855374\n[잡담] 왕가슴 아르고스\n[28]\n사진\n파타1 12:55 3,361 36', '5855262\n[잡담] 스포) 아만 이ㅅㄲ 미친놈임?\n[43]\n사진\n장랑삿령숙 12:34 9,005 46']
# ['5855417\n[잡담] 뉴비 세구 60각 주차 완료.\n[26]\n사진\n팩폭전과17범 13:04 3,766 45', '5855411\n[잡담] 스포)황혼의 목적\n[38]\n사진\nGrunty 13:03 4,221 71', '5855374\n[잡담] 왕가슴 아르고스\n[28]\n사진\n파타1 12:55 3,361 36', '5855262\n[잡담] 스포) 아만 이ㅅㄲ 미친놈임?\n[43]\n사진\n장랑삿령숙 12:34 9,005 46', '5855190\n[잡담] 소신발언) 여정퀘 스킵 안되게 해주세요\n[26]\nDarak77 12:20 2,946 35']
# ...

# %%
content = driver.find_element(By.ID,'powerbbsContent').text

# %%
print(content)
# Out:
# 좀 늦었지만 초창기 목표였던 헬카멘 칭호도 땄고, 세구 초월60각 완료했음
#
# 장비는 세트5렙 방어구 올신화 계승 19강, 무기는 22강 장기백 진행 중 ㅠㅠ
#
# 지금 1996렙이라 방어구 다 20으로 붙이면 20층 쌉가능하긴 한데
# 몇 번 누르니까 존나게찬란한돌파석이 없다. 무기 한번 누르는데 치킨 네 마리더라.
#
# 아니면, 창고에 88돌 하나 있는데 7/3 신화악세로 싹 바꿔줄까.
# 333331 에서  3333222 세팅하면 얼마나 쎄짐?
